# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# Run it for testing

# %%
# Set default values
no_gpu = False
save_name = './results_tmp'
load_name = '/content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch60_bs4.pth'
test_batch_size = 1
num_workers = 1
color = True
burst_length = 1
blind_est = True
kernel_size = [3]
sep_conv = False
channel_att = False
spatial_att = False
upMode = 'bilinear'
core_bias = False
init_type = 'xavier'
init_gain = 0.02
baseroot = 'rainy_image_dataset/testing'
crop = False
crop_size = 512
geometry_aug = False
angle_aug = False
scale_min = 1.0
scale_max = 1.0
add_noise = False
mu = 0
sigma = 30

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# ----------------------------------------
#         Initialize the networks
# ----------------------------------------
def weights_init(net, init_type = 'normal', init_gain = 0.02):
    """Initialize network weights.
    Parameters:
        net (network)   -- network to be initialized
        init_type (str) -- the name of an initialization method: normal | xavier | kaiming | orthogonal
        init_gain (float)    -- scaling factor for normal, xavier and orthogonal
    In our paper, we choose the default setting: zero mean Gaussian distribution with a standard deviation of 0.02
    """
    def init_func(m):
        classname = m.__class__.__name__
        if hasattr(m, 'weight') and classname.find('Conv') != -1:
            if init_type == 'normal':
                torch.nn.init.normal_(m.weight.data, 0.0, init_gain)
            elif init_type == 'xavier':
                torch.nn.init.xavier_normal_(m.weight.data, gain = init_gain)
            elif init_type == 'kaiming':
                torch.nn.init.kaiming_normal_(m.weight.data, a = 0, mode = 'fan_in')
            elif init_type == 'orthogonal':
                torch.nn.init.orthogonal_(m.weight.data, gain = init_gain)
            else:
                raise NotImplementedError('initialization method [%s] is not implemented' % init_type)
        elif classname.find('BatchNorm2d') != -1:
            torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
            torch.nn.init.constant_(m.bias.data, 0.0)

    # apply the initialization function <init_func>
    print('initialize network with %s type' % init_type)
    net.apply(init_func)

# ----------------------------------------
#      Kernel Prediction Network (KPN)
# ----------------------------------------
class Basic(nn.Module):
    def __init__(self, in_ch, out_ch, g=16, channel_att=False, spatial_att=False):
        super(Basic, self).__init__()
        self.channel_att = channel_att
        self.spatial_att = spatial_att
        self.conv1 = nn.Sequential(
                nn.Conv2d(in_channels=in_ch, out_channels=out_ch, kernel_size=3, stride=1, padding=1),
                # nn.BatchNorm2d(out_ch),
                nn.ReLU(),
                nn.Conv2d(in_channels=out_ch, out_channels=out_ch, kernel_size=3, stride=1, padding=1),
                # nn.BatchNorm2d(out_ch),
                nn.ReLU(),
                nn.Conv2d(in_channels=out_ch, out_channels=out_ch, kernel_size=3, stride=1, padding=1),
                # nn.BatchNorm2d(out_ch),
                nn.ReLU()
            )

        if channel_att:
            self.att_c = nn.Sequential(
                nn.Conv2d(2*out_ch, out_ch//g, 1, 1, 0),
                nn.ReLU(),
                nn.Conv2d(out_ch//g, out_ch, 1, 1, 0),
                nn.Sigmoid()
            )
        if spatial_att:
            self.att_s = nn.Sequential(
                nn.Conv2d(in_channels=2, out_channels=1, kernel_size=7, stride=1, padding=3),
                nn.Sigmoid()
            )

    def forward(self, data):
        """
        Forward function.
        :param data:
        :return: tensor
        """
        fm = self.conv1(data)
        if self.channel_att:
            # fm_pool = F.adaptive_avg_pool2d(fm, (1, 1)) + F.adaptive_max_pool2d(fm, (1, 1))
            fm_pool = torch.cat([F.adaptive_avg_pool2d(fm, (1, 1)), F.adaptive_max_pool2d(fm, (1, 1))], dim=1)
            att = self.att_c(fm_pool)
            fm = fm * att
        if self.spatial_att:
            fm_pool = torch.cat([torch.mean(fm, dim=1, keepdim=True), torch.max(fm, dim=1, keepdim=True)[0]], dim=1)
            att = self.att_s(fm_pool)
            fm = fm * att
        return fm

class KPN(nn.Module):
    def __init__(self, color=True, burst_length=1, blind_est=True, kernel_size=[5], sep_conv=False,
                 channel_att=False, spatial_att=False, upMode='bilinear', core_bias=False):
        super(KPN, self).__init__()
        self.upMode = upMode
        self.burst_length = burst_length
        self.core_bias = core_bias
        self.color_channel = 3 if color else 1
        in_channel = (3 if color else 1) * (burst_length if blind_est else burst_length+1)
        out_channel = (3 if color else 1) * (2 * sum(kernel_size) if sep_conv else np.sum(np.array(kernel_size) ** 2)) * burst_length
        if core_bias:
            out_channel += (3 if color else 1) * burst_length
        # 各个卷积层定义
        # 2~5层都是均值池化+3层卷积
        self.conv1 = Basic(in_channel, 64, channel_att=False, spatial_att=False)
        self.conv2 = Basic(64, 128, channel_att=False, spatial_att=False)
        self.conv3 = Basic(128, 256, channel_att=False, spatial_att=False)
        self.conv4 = Basic(256, 512, channel_att=False, spatial_att=False)
        self.conv5 = Basic(512, 512, channel_att=False, spatial_att=False)
        # 6~8层要先上采样再卷积
        self.conv6 = Basic(512+512, 512, channel_att=channel_att, spatial_att=spatial_att)
        self.conv7 = Basic(256+512, 256, channel_att=channel_att, spatial_att=spatial_att)
        self.conv8 = Basic(256+128, out_channel, channel_att=channel_att, spatial_att=spatial_att)
        self.outc = nn.Conv2d(out_channel, out_channel, 1, 1, 0)

        self.kernel_pred = KernelConv(kernel_size, sep_conv, self.core_bias)

        self.conv_final = nn.Conv2d(in_channels=12, out_channels=3, kernel_size=3, stride=1, padding=1)

    # 前向传播函数
    def forward(self, data_with_est, data, white_level=1.0):
        """
        forward and obtain pred image directly
        :param data_with_est: if not blind estimation, it is same as data
        :param data:
        :return: pred_img_i and img_pred
        """
        conv1 = self.conv1(data_with_est)
        conv2 = self.conv2(F.avg_pool2d(conv1, kernel_size=2, stride=2))
        conv3 = self.conv3(F.avg_pool2d(conv2, kernel_size=2, stride=2))
        conv4 = self.conv4(F.avg_pool2d(conv3, kernel_size=2, stride=2))
        conv5 = self.conv5(F.avg_pool2d(conv4, kernel_size=2, stride=2))
        # 开始上采样  同时要进行skip connection
        conv6 = self.conv6(torch.cat([conv4, F.interpolate(conv5, scale_factor=2, mode=self.upMode)], dim=1))
        conv7 = self.conv7(torch.cat([conv3, F.interpolate(conv6, scale_factor=2, mode=self.upMode)], dim=1))
        #print(conv7.size())
        conv8 = self.conv8(torch.cat([conv2, F.interpolate(conv7, scale_factor=2, mode=self.upMode)], dim=1))
        # return channel K*K*N
        core = self.outc(F.interpolate(conv8, scale_factor=2, mode=self.upMode))

        pred1 = self.kernel_pred(data, core, white_level, rate=1)
        pred2 = self.kernel_pred(data, core, white_level, rate=2)
        pred3 = self.kernel_pred(data, core, white_level, rate=3)
        pred4 = self.kernel_pred(data, core, white_level, rate=4)

        pred_cat = torch.cat([torch.cat([torch.cat([pred1, pred2], dim=1), pred3], dim=1), pred4], dim=1)

        pred = self.conv_final(pred_cat)

        #pred = self.kernel_pred(data, core, white_level, rate=1)

        return pred

class KernelConv(nn.Module):
    """
    the class of computing prediction
    """
    def __init__(self, kernel_size=[5], sep_conv=False, core_bias=False):
        super(KernelConv, self).__init__()
        self.kernel_size = sorted(kernel_size)
        self.sep_conv = sep_conv
        self.core_bias = core_bias

    def _sep_conv_core(self, core, batch_size, N, color, height, width):
        """
        convert the sep_conv core to conv2d core
        2p --> p^2
        :param core: shape: batch*(N*2*K)*height*width
        :return:
        """
        kernel_total = sum(self.kernel_size)
        core = core.view(batch_size, N, -1, color, height, width)
        if not self.core_bias:
            core_1, core_2 = torch.split(core, kernel_total, dim=2)
        else:
            core_1, core_2, core_3 = torch.split(core, kernel_total, dim=2)
        # output core
        core_out = {}
        cur = 0
        for K in self.kernel_size:
            t1 = core_1[:, :, cur:cur + K, ...].view(batch_size, N, K, 1, 3, height, width)
            t2 = core_2[:, :, cur:cur + K, ...].view(batch_size, N, 1, K, 3, height, width)
            core_out[K] = torch.einsum('ijklno,ijlmno->ijkmno', [t1, t2]).view(batch_size, N, K * K, color, height, width)
            cur += K
        # it is a dict
        return core_out, None if not self.core_bias else core_3.squeeze()

    def _convert_dict(self, core, batch_size, N, color, height, width):
        """
        make sure the core to be a dict, generally, only one kind of kernel size is suitable for the func.
        :param core: shape: batch_size*(N*K*K)*height*width
        :return: core_out, a dict
        """
        core_out = {}
        core = core.view(batch_size, N, -1, color, height, width)
        core_out[self.kernel_size[0]] = core[:, :, 0:self.kernel_size[0]**2, ...]
        bias = None if not self.core_bias else core[:, :, -1, ...]
        return core_out, bias

    def forward(self, frames, core, white_level=1.0, rate=1):
        """
        compute the pred image according to core and frames
        :param frames: [batch_size, N, 3, height, width]
        :param core: [batch_size, N, dict(kernel), 3, height, width]
        :return:
        """
        if len(frames.size()) == 5:
            batch_size, N, color, height, width = frames.size()
        else:
            batch_size, N, height, width = frames.size()
            color = 1
            frames = frames.view(batch_size, N, color, height, width)
        if self.sep_conv:
            core, bias = self._sep_conv_core(core, batch_size, N, color, height, width)
        else:
            core, bias = self._convert_dict(core, batch_size, N, color, height, width)
        img_stack = []
        pred_img = []
        kernel = self.kernel_size[::-1]
        for index, K in enumerate(kernel):
            if not img_stack:
                padding_num = (K//2) * rate
                frame_pad = F.pad(frames, [padding_num, padding_num, padding_num, padding_num])
                for i in range(0, K):
                    for j in range(0, K):
                        img_stack.append(frame_pad[..., i*rate:i*rate + height, j*rate:j*rate + width])
                img_stack = torch.stack(img_stack, dim=2)
            else:
                k_diff = (kernel[index - 1] - kernel[index]) // 2
                img_stack = img_stack[:, :, k_diff:-k_diff, ...]
            # print('img_stack:', img_stack.size())
            pred_img.append(torch.sum(
                core[K].mul(img_stack), dim=2, keepdim=False
            ))
        pred_img = torch.stack(pred_img, dim=0)
        # print('pred_stack:', pred_img.size())
        pred_img_i = torch.mean(pred_img, dim=0, keepdim=False)
        #print("pred_img_i", pred_img_i.size())
        # N = 1
        pred_img_i = pred_img_i.squeeze(2)
        #print("pred_img_i", pred_img_i.size())
        # if bias is permitted
        if self.core_bias:
            if bias is None:
                raise ValueError('The bias should not be None.')
            pred_img_i += bias
        # print('white_level', white_level.size())
        pred_img_i = pred_img_i / white_level
        #pred_img = torch.mean(pred_img_i, dim=1, keepdim=True)
        # print('pred_img:', pred_img.size())
        # print('pred_img_i:', pred_img_i.size())
        return pred_img_i

class LossFunc(nn.Module):
    """
    loss function of KPN
    """
    def __init__(self, coeff_basic=1.0, coeff_anneal=1.0, gradient_L1=True, alpha=0.9998, beta=100):
        super(LossFunc, self).__init__()
        self.coeff_basic = coeff_basic
        self.coeff_anneal = coeff_anneal
        self.loss_basic = LossBasic(gradient_L1)
        self.loss_anneal = LossAnneal(alpha, beta)

    def forward(self, pred_img_i, pred_img, ground_truth, global_step):
        """
        forward function of loss_func
        :param frames: frame_1 ~ frame_N, shape: [batch, N, 3, height, width]
        :param core: a dict coverted by ......
        :param ground_truth: shape [batch, 3, height, width]
        :param global_step: int
        :return: loss
        """
        return self.coeff_basic * self.loss_basic(pred_img, ground_truth), self.coeff_anneal * self.loss_anneal(global_step, pred_img_i, ground_truth)

class LossBasic(nn.Module):
    """
    Basic loss function.
    """
    def __init__(self, gradient_L1=True):
        super(LossBasic, self).__init__()
        self.l1_loss = nn.L1Loss()
        self.l2_loss = nn.MSELoss()
        self.gradient = TensorGradient(gradient_L1)

    def forward(self, pred, ground_truth):
        return self.l2_loss(pred, ground_truth) + \
               self.l1_loss(self.gradient(pred), self.gradient(ground_truth))

class LossAnneal(nn.Module):
    """
    anneal loss function
    """
    def __init__(self, alpha=0.9998, beta=100):
        super(LossAnneal, self).__init__()
        self.global_step = 0
        self.loss_func = LossBasic(gradient_L1=True)
        self.alpha = alpha
        self.beta = beta

    def forward(self, global_step, pred_i, ground_truth):
        """
        :param global_step: int
        :param pred_i: [batch_size, N, 3, height, width]
        :param ground_truth: [batch_size, 3, height, width]
        :return:
        """
        loss = 0
        for i in range(pred_i.size(1)):
            loss += self.loss_func(pred_i[:, i, ...], ground_truth)
        loss /= pred_i.size(1)
        return self.beta * self.alpha ** global_step * loss

class TensorGradient(nn.Module):
    """
    the gradient of tensor
    """
    def __init__(self, L1=True):
        super(TensorGradient, self).__init__()
        self.L1 = L1

    def forward(self, img):
        w, h = img.size(-2), img.size(-1)
        l = F.pad(img, [1, 0, 0, 0])
        r = F.pad(img, [0, 1, 0, 0])
        u = F.pad(img, [0, 0, 1, 0])
        d = F.pad(img, [0, 0, 0, 1])
        if self.L1:
            return torch.abs((l - r)[..., 0:w, 0:h]) + torch.abs((u - d)[..., 0:w, 0:h])
        else:
            return torch.sqrt(
                torch.pow((l - r)[..., 0:w, 0:h], 2) + torch.pow((u - d)[..., 0:w, 0:h], 2)
            )

if __name__ == '__main__':

    kpn = KPN().cuda()
    a = torch.randn(4, 3, 224, 224).cuda()
    b = kpn(a, a)
    print(b.shape)
# Out:
# torch.Size([4, 3, 224, 224])

# %%
import os
import cv2
import skimage
import numpy as np
import torch
import torch.nn as nn
import torchvision as tv
import math

# ----------------------------------------
#                 Network
# ----------------------------------------
def create_generator():
    # Initialize the network
    generator = KPN(color, burst_length, blind_est, kernel_size, sep_conv, \
        channel_att, spatial_att, upMode, core_bias)
    if load_name == '':
        # Init the network
        weights_init(generator, init_type = init_type, init_gain = init_gain)
        print('Generator is created!')
    else:
        # Load a pre-trained network
        pretrained_net = torch.load(load_name)
        load_dict(generator, pretrained_net)
        print('Generator is loaded!')
    return generator

def load_dict(process_net, pretrained_net):
    # Get the dict from pre-trained network
    pretrained_dict = pretrained_net
    # Get the dict from processing network
    process_dict = process_net.state_dict()
    # Delete the extra keys of pretrained_dict that do not belong to process_dict
    pretrained_dict = {k: v for k, v in pretrained_dict.items() if k in process_dict}
    # Update process_dict using pretrained_dict
    process_dict.update(pretrained_dict)
    # Load the updated dict to processing network
    process_net.load_state_dict(process_dict)
    return process_net

# ----------------------------------------
#    Validation and Sample at training
# ----------------------------------------
def save_sample_png(sample_folder, sample_name, img_list, name_list, pixel_max_cnt = 255, height = -1, width = -1):
    # Save image one-by-one
    for i in range(len(img_list)):
        img = img_list[i]
        # Recover normalization
        img = img * 255.0
        # Process img_copy and do not destroy the data of img
        #print(img.size())
        img_copy = img.clone().data.permute(0, 2, 3, 1).cpu().numpy()
        img_copy = np.clip(img_copy, 0, pixel_max_cnt)
        img_copy = img_copy.astype(np.uint8)[0, :, :, :]
        img_copy = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
        if (height != -1) and (width != -1):
            img_copy = cv2.resize(img_copy, (width, height))
        # Save to certain path
        save_img_name = sample_name + '_' + name_list[i] + '.png'
        save_img_path = os.path.join(sample_folder, save_img_name)
        cv2.imwrite(save_img_path, img_copy)

def save_sample_png_test(sample_folder, sample_name, img_list, name_list, pixel_max_cnt = 255):
    # Save image one-by-one
    for i in range(len(img_list)):
        img = img_list[i]
        # Recover normalization
        img = img * 255.0
        # Process img_copy and do not destroy the data of img
        img_copy = img.clone().data.permute(0, 2, 3, 1).cpu().numpy()
        img_copy = np.clip(img_copy, 0, pixel_max_cnt)
        img_copy = img_copy.astype(np.uint8)[0, :, :, :]
        img_copy = img_copy.astype(np.float32)
        img_copy = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
        # Save to certain path
        save_img_name = sample_name + '_' + name_list[i] + '.png'
        save_img_path = os.path.join(sample_folder, save_img_name)
        cv2.imwrite(save_img_path, img_copy)

def recover_process(img, height = -1, width = -1):
    img = img * 255.0
    img_copy = img.clone().data.permute(0, 2, 3, 1).cpu().numpy()
    img_copy = np.clip(img_copy, 0, 255)
    img_copy = img_copy.astype(np.uint8)[0, :, :, :]
    img_copy = img_copy.astype(np.float32)
    img_copy = cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB)
    if (height != -1) and (width != -1):
        img_copy = cv2.resize(img_copy, (width, height))
    return img_copy

def psnr(pred, target):
    #print(pred.shape)
    #print(target.shape)
    mse = np.mean( (pred - target) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

def grey_psnr(pred, target, pixel_max_cnt = 255):
    pred = torch.sum(pred, dim = 0)
    target = torch.sum(target, dim = 0)
    mse = torch.mul(target - pred, target - pred)
    rmse_avg = (torch.mean(mse).item()) ** 0.5
    p = 20 * np.log10(pixel_max_cnt * 3 / rmse_avg)
    return p

def ssim(pred, target):
    pred = pred.clone().data.permute(0, 2, 3, 1).cpu().numpy()
    target = target.clone().data.permute(0, 2, 3, 1).cpu().numpy()
    target = target[0]
    pred = pred[0]
    ssim = skimage.measure.compare_ssim(target, pred, multichannel = True)
    return ssim

# ----------------------------------------
#             PATH processing
# ----------------------------------------
def check_path(path):
    if not os.path.exists(path):
        os.makedirs(path)

def savetxt(name, loss_log):
    np_loss_log = np.array(loss_log)
    np.savetxt(name, np_loss_log)


#rain100H/L / SPA
def get_files(path):
    if ('rain1400' in path):
        ret = []
        path_rainy = path + "/rainy_image"
        path_gt = path + "/ground_truth"

        for root, dirs, files in os.walk(path_gt):
            files.sort()
            for name in files:
                if name.split('.')[1] != "jpg":
                    continue
                id = name.split('.')[0]
                file_gt = path_gt + "/" + id + ".jpg"
                for i in range(1, 15):
                    file_rainy = path_rainy + "/" + id + "_" + str(i) + ".jpg"
                    ret.append([file_rainy, file_gt])
        return ret
    else:
        ret = []
        path_rainy = path + "/rain"
        path_gt = path + "/norain"

        for root, dirs, files in os.walk(path_rainy):
            files.sort()

            for name in files:
                if name.split('.')[1] != 'png':
                    continue
                file_rainy = path_rainy + "/" + name
                file_gt = path_gt + "/" + name
                ret.append([file_rainy, file_gt])
        return ret

def get_jpgs(path):
    # read a folder, return the image name
    ret = []
    for root, dirs, files in os.walk(path):
        for filespath in files:
            ret.append(filespath)
    return ret

def get_last_2paths(path):
    # read a folder, return the image name
    ret = []
    for root, dirs, files in os.walk(path):
        for filespath in files:
            if filespath[-4:] == '.png':
                wholepath = os.path.join(root, filespath)
                last_2paths = os.path.join(wholepath.split('/')[-2], wholepath.split('/')[-1])
                ret.append(last_2paths)
    return ret

def text_readlines(filename):
    # Try to read a txt file and return a list.Return [] if there was a mistake.
    try:
        file = open(filename, 'r')
    except IOError:
        error = []
        return error
    content = file.readlines()
    # This for loop deletes the EOF (like \n)
    for i in range(len(content)):
        content[i] = content[i][:len(content[i])-1]
    file.close()
    return content

def text_save(content, filename, mode = 'a'):
    # save a list to a txt
    # Try to save a list variable in txt file.
    file = open(filename, mode)
    for i in range(len(content)):
        file.write(str(content[i]))
    file.close()

# %%
"""Base augmentations operators."""

import numpy as np
from PIL import Image, ImageOps, ImageEnhance

# ImageNet code should change this value
#IMAGE_SIZE = 256


def int_parameter(level, maxval):
  """Helper function to scale `val` between 0 and maxval .

  Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.

  Returns:
    An int that results from scaling `maxval` according to `level`.
  """
  return int(level * maxval / 10)


def float_parameter(level, maxval):
  """Helper function to scale `val` between 0 and maxval.

  Args:
    level: Level of the operation that will be between [0, `PARAMETER_MAX`].
    maxval: Maximum value that the operation can have. This will be scaled to
      level/PARAMETER_MAX.

  Returns:
    A float that results from scaling `maxval` according to `level`.
  """
  return float(level) * maxval / 10.


def sample_level(n):
  return np.random.uniform(low=0.1, high=n)


def autocontrast(pil_img, _):
  return ImageOps.autocontrast(pil_img)


def equalize(pil_img, _):
  return ImageOps.equalize(pil_img)


def posterize(pil_img, level):
  level = int_parameter(sample_level(level), 4)
  return ImageOps.posterize(pil_img, 4 - level)


def rotate(pil_img, level):
  degrees = int_parameter(sample_level(level), 30)
  if np.random.uniform() > 0.5:
    degrees = -degrees
  return pil_img.rotate(degrees, resample=Image.BILINEAR)


def solarize(pil_img, level):
  level = int_parameter(sample_level(level), 256)
  return ImageOps.solarize(pil_img, 256 - level)


def shear_x(pil_img, level):
  level = float_parameter(sample_level(level), 0.3)
  if np.random.uniform() > 0.5:
    level = -level
  return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (1, level, 0, 0, 1, 0),
                           resample=Image.BILINEAR)


def shear_y(pil_img, level):
  level = float_parameter(sample_level(level), 0.3)
  if np.random.uniform() > 0.5:
    level = -level
  return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (1, 0, 0, level, 1, 0),
                           resample=Image.BILINEAR)


def translate_x(pil_img, level):
  level = int_parameter(sample_level(level), pil_img.width / 3)
  if np.random.random() > 0.5:
    level = -level
  return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (1, 0, level, 0, 1, 0),
                           resample=Image.BILINEAR)


def translate_y(pil_img, level):
  level = int_parameter(sample_level(level), pil_img.height / 3)
  if np.random.random() > 0.5:
    level = -level
  return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (1, 0, 0, 0, 1, level),
                           resample=Image.BILINEAR)


# operation that overlaps with ImageNet-C's test set
def color(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Color(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def contrast(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Contrast(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def brightness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Brightness(pil_img).enhance(level)


# operation that overlaps with ImageNet-C's test set
def sharpness(pil_img, level):
    level = float_parameter(sample_level(level), 1.8) + 0.1
    return ImageEnhance.Sharpness(pil_img).enhance(level)

def zoom_x(pil_img, level):
    level = float_parameter(sample_level(level), 6.0)
    rate = 1.0/level
    if np.random.random() > 0.5:
        bias = pil_img.width*(1-rate)
    else:
        bias = 0
    return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (rate, 0, bias, 0, 1, 0),
                           resample=Image.BILINEAR)


def zoom_y(pil_img, level):
    level = float_parameter(sample_level(level), 6.0)
    rate = 1.0/level
    if np.random.random() > 0.5:
        bias = pil_img.height*(1-rate)
    else:
        bias = 0
    return pil_img.transform((pil_img.width, pil_img.height),
                           Image.AFFINE, (1, 0, 0, 0, rate, bias),
                           resample=Image.BILINEAR)


augmentations = [
    rotate, shear_x, shear_y,
    translate_x, translate_y, zoom_x, zoom_y
]

'''
augmentations = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y
]
'''

augmentations_all = [
    autocontrast, equalize, posterize, rotate, solarize, shear_x, shear_y,
    translate_x, translate_y, color, contrast, brightness, sharpness
]

# %%
"""Reference implementation of AugMix's data augmentation method in numpy."""
import numpy as np
import random
from PIL import Image

# CIFAR-10 constants
MEAN = [0.4914, 0.4822, 0.4465]
STD = [0.2023, 0.1994, 0.2010]


def normalize(image):
  """Normalize input image channel-wise to zero mean and unit variance."""
  '''
  image = image.transpose(2, 0, 1)  # Switch to channel-first
  mean, std = np.array(MEAN), np.array(STD)
  image = (image - mean[:, None, None]) / std[:, None, None]
  return image.transpose(1, 2, 0)
  '''
  return image

def apply_op(image, op, severity):
  image = np.clip(image * 255., 0, 255).astype(np.uint8)
  pil_img = Image.fromarray(image)  # Convert to PIL.Image
  pil_img = op(pil_img, severity)
  return np.asarray(pil_img) / 255.


def augment_and_mix(image, severity=3, width=3, depth=-1, alpha=1.):
  """Perform AugMix augmentations and compute mixture.

  Args:
    image: Raw input image as float32 np.ndarray of shape (h, w, c)
    severity: Severity of underlying augmentation operators (between 1 to 10).
    width: Width of augmentation chain
    depth: Depth of augmentation chain. -1 enables stochastic depth uniformly
      from [1, 3]
    alpha: Probability coefficient for Beta and Dirichlet distributions.

  Returns:
    mixed: Augmented and mixed image.
  """
  ws = np.float32(
      np.random.dirichlet([alpha] * width))
  m = np.float32(np.random.beta(alpha, alpha))

  mix = np.zeros_like(image)
  for i in range(width):
    image_aug = image.copy()
    depth = depth if depth > 0 else np.random.randint(2, 4)
    for _ in range(depth):
      op = np.random.choice(augmentations)
      #print(op)
      image_aug = apply_op(image_aug, op, severity)
    # Preprocessing commutes since all coefficients are convex
    mix += ws[i] * normalize(image_aug)

  max_ws = max(ws)
  rate = 1.0 / max_ws
  #print(rate)


  #mixed = (random.randint(5000, 9000)/10000) * normalize(image) + (random.randint((int)(rate*3000), (int)(rate*10000))/10000) * mix
  mixed = max((1 - m), 0.7) * normalize(image) + max(m, rate*0.5) * mix
  #mixed = (1 - m) * normalize(image) + m * mix
  return mixed

# %%
import os
import random
import numpy as np
import cv2
import math
import torch
from torch.utils.data import Dataset
from torchvision import transforms

class RandomCrop(object):
    def __init__(self, image_size, crop_size):
        self.ch, self.cw = crop_size
        ih, iw = image_size

        self.h1 = random.randint(0, ih - self.ch)
        self.w1 = random.randint(0, iw - self.cw)

        self.h2 = self.h1 + self.ch
        self.w2 = self.w1 + self.cw

    def __call__(self, img):
        if len(img.shape) == 3:
            return img[self.h1: self.h2, self.w1: self.w2, :]
        else:
            return img[self.h1: self.h2, self.w1: self.w2]

class DenoisingDataset(Dataset):
    def __init__(self):                                   		    # root: list ; transform: torch transform
        self.imglist = get_files(baseroot)
        self.rainaug = rainaug
        '''
        for pair in self.imglist:
            print(pair[0] + ' | ' + pair[1])
        '''
    def getRainLayer2(self, rand_id1, rand_id2):
        path_img_rainlayer_src = "./rainmix/Streaks_Garg06/" + str(rand_id1) + "-" + str(rand_id2) + ".png"
        rainlayer_rand = cv2.imread(path_img_rainlayer_src).astype(np.float32) / 255.0
        rainlayer_rand = cv2.cvtColor(rainlayer_rand, cv2.COLOR_BGR2RGB)
        return rainlayer_rand

    def getRandRainLayer2(self):
        rand_id1 = random.randint(1, 165)
        rand_id2 = random.randint(4, 8)
        rainlayer_rand = self.getRainLayer2(rand_id1, rand_id2)
        return rainlayer_rand

    def rain_aug(self, img_rainy, img_gt):
        img_rainy = (img_rainy.astype(np.float32)) / 255.0
        img_gt = (img_gt.astype(np.float32)) / 255.0
        if random.randint(0, 10) > 3:
            img_rainy_ret = img_rainy
        else:
            img_rainy_ret = img_gt
        img_gt_ret = img_gt

        rainlayer_rand2 = self.getRandRainLayer2()
        rainlayer_aug2 = augment_and_mix(rainlayer_rand2, severity = 3, width = 3, depth = -1) * 1
        #rainlayer_rand2ex = self.getRandRainLayer2()
        #rainlayer_aug2ex = augment_and_mix.augment_and_mix(rainlayer_rand2ex, severity = 3, width = 3, depth = -1) * 1

        height = min(img_gt.shape[0], rainlayer_aug2.shape[0])
        width = min(img_gt.shape[1], rainlayer_aug2.shape[1])
        #height = min(img_gt.shape[0], min(rainlayer_aug2.shape[0], rainlayer_aug2ex.shape[0]))
        #width = min(img_gt.shape[1], min(rainlayer_aug2.shape[1], rainlayer_aug2ex.shape[1]))

        cropper = RandomCrop(rainlayer_aug2.shape[:2], (height, width))
        rainlayer_aug2_crop = cropper(rainlayer_aug2)
        #cropper = RandomCrop(rainlayer_aug2ex.shape[:2], (height, width))
        #rainlayer_aug2ex_crop = cropper(rainlayer_aug2ex)
        #print(height, width, rainlayer_aug2_crop.shape, rainlayer_aug2ex_crop.shape)
        #rainlayer_aug2_crop = rainlayer_aug2_crop + rainlayer_aug2ex_crop
        cropper = RandomCrop(img_gt_ret.shape[:2], (height, width))
        img_rainy_ret = cropper(img_rainy_ret)
        img_gt_ret = cropper(img_gt_ret)
        img_rainy_ret = img_rainy_ret + rainlayer_aug2_crop - img_rainy_ret*rainlayer_aug2_crop
        np.clip(img_rainy_ret, 0.0, 1.0)

        img_rainy_ret = img_rainy_ret * 255
        img_gt_ret = img_gt_ret * 255

        #cv2.imwrite("./temp/temp.jpg", cv2.cvtColor(img_rainy_ret, cv2.COLOR_RGB2BGR))

        return img_rainy_ret, img_gt_ret

    def __getitem__(self, index):
        ## read an image
        img_rainy = cv2.imread(self.imglist[index][0])
        img_gt = cv2.imread(self.imglist[index][1])

        img_rainy = cv2.cvtColor(img_rainy, cv2.COLOR_BGR2RGB)

        img_gt = cv2.cvtColor(img_gt, cv2.COLOR_BGR2RGB)

        if self.rainaug:
            img_rainy, img_gt = self.rain_aug(img_rainy, img_gt)

        # random crop
        cropper = RandomCrop(img_gt.shape[:2], (crop_size, crop_size))
        img_rainy = cropper(img_rainy)
        img_gt = cropper(img_gt)
        # random rotate and horizontal flip
        # according to paper, these two data augmentation methods are recommended
        if angle_aug:
            rotate = random.randint(0, 3)
            if rotate != 0:
                img_rainy = np.rot90(img_rainy, rotate)
                img_gt = np.rot90(img_gt, rotate)
            if np.random.random() >= 0.5:
                img_rainy = cv2.flip(img_rainy, flipCode = 0)
                img_gt = cv2.flip(img_gt, flipCode = 0)

        # normalization
        img_rainy = img_rainy.astype(np.float32) # RGB image in range [0, 255]
        img_gt = img_gt.astype(np.float32) # RGB image in range [0, 255]
        img_rainy = img_rainy / 255.0
        img_rainy = torch.from_numpy(img_rainy.transpose(2, 0, 1)).contiguous()
        img_gt = img_gt / 255.0
        img_gt = torch.from_numpy(img_gt.transpose(2, 0, 1)).contiguous()

        return img_rainy, img_gt

    def __len__(self):
        return len(self.imglist)

class DenoisingValDataset(Dataset):
    def __init__(self):                                   		    # root: list ; transform: torch transform
        self.imglist = get_files(baseroot)

    def __getitem__(self, index):
        ## read an image
        img_rainy = cv2.imread(self.imglist[index][0])
        img_gt = cv2.imread(self.imglist[index][1])

        height = img_rainy.shape[0]
        width = img_rainy.shape[1]
        height_origin = height
        width_origin = width
        if height % 16 != 0:
            height = ((height // 16) + 1) * 16
        if width % 16 !=0:
            width = ((width // 16) + 1) * 16
        img_rainy = cv2.resize(img_rainy, (width, height))
        img_gt = cv2.resize(img_gt, (width, height))

        img_rainy = cv2.cvtColor(img_rainy, cv2.COLOR_BGR2RGB)
        img_gt = cv2.cvtColor(img_gt, cv2.COLOR_BGR2RGB)

        # random crop
        if crop:
            cropper = RandomCrop(img_rainy.shape[:2], (crop_size, crop_size))
            img_rainy = cropper(img_rainy)
            img_gt = cropper(img_gt)
        # random rotate and horizontal flip
        # according to paper, these two data augmentation methods are recommended
        if angle_aug:
            rotate = random.randint(0, 3)
            if rotate != 0:
                img_rainy = np.rot90(img_rainy, rotate)
                img_gt = np.rot90(img_gt, rotate)
            if np.random.random() >= 0.5:
                img_rainy = cv2.flip(img_rainy, flipCode = 0)
                img_gt = cv2.flip(img_gt, flipCode = 0)

        # normalization
        img_rainy = img_rainy.astype(np.float32) # RGB image in range [0, 255]
        img_gt = img_gt.astype(np.float32) # RGB image in range [0, 255]
        img_rainy = img_rainy / 255.0
        img_rainy = torch.from_numpy(img_rainy.transpose(2, 0, 1)).contiguous()
        img_gt = img_gt / 255.0
        img_gt = torch.from_numpy(img_gt.transpose(2, 0, 1)).contiguous()

        return img_rainy, img_gt, height_origin, width_origin

    def __len__(self):
        return len(self.imglist)

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown 1IBENJqN6XU5HMlSQ2W7jkdW22Z1x4W9K
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IBENJqN6XU5HMlSQ2W7jkdW22Z1x4W9K
# To: /content/datasets_Synthetic_EfficientDerain.zip
# 100% 1.82G/1.82G [00:23<00:00, 76.4MB/s]

# %%
# !gdown 1gXckj9HTsJpzt9VZGlr8Akbp3XILAqZ4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gXckj9HTsJpzt9VZGlr8Akbp3XILAqZ4
# To: /content/Models.zip
# 100% 4.41G/4.41G [01:00<00:00, 73.3MB/s]

# %%
# !unzip '/content/datasets_Synthetic_EfficientDerain.zip' -d '/content/derain/'
# !unzip '/content/Models.zip' -d '/content/derain/'
# Out:
# Archive:  /content/TestData.zip
#    creating: /content/derain/TestData/
#    creating: /content/derain/TestData/input_100L/
#   inflating: /content/derain/TestData/input_100L/rain-001.png
#   inflating: /content/derain/TestData/input_100L/rain-002.png
#   inflating: /content/derain/TestData/input_100L/rain-003.png
#   inflating: /content/derain/TestData/input_100L/rain-004.png
#   inflating: /content/derain/TestData/input_100L/rain-005.png
#   inflating: /content/derain/TestData/input_100L/rain-006.png
#   inflating: /content/derain/TestData/input_100L/rain-007.png
#   inflating: /content/derain/TestData/input_100L/rain-008.png
#   inflating: /content/derain/TestData/input_100L/rain-009.png
#   inflating: /content/derain/TestData/input_100L/rain-010.png
#   inflating: /content/derain/TestData/input_100L/rain-011.png
#   inflating: /content/derain/TestData/input_100L/rain-012.png
#   inflating: /content/derain/TestData/input_100L/rain-013.png
#   inflating: /content/derain/TestData/input_100L/rain-014.png
#   inflating: /content/derain/TestData/input_100L/rain-015.png
#   inflating: /content/derain/TestData/input_100L/rain-016.png
#   inflating: /content/derain/TestData/input_100L/rain-017.png
#   inflating: /content/derain/TestData/input_100L/rain-018.png
#   inflating: /content/derain/TestData/input_100L/rain-019.png
#   inflating: /content/derain/TestData/input_100L/rain-020.png
#   inflating: /content/derain/TestData/input_100L/rain-021.png
#   inflating: /content/derain/TestData/input_100L/rain-022.png
#   inflating: /content/derain/TestData/input_100L/rain-023.png
#   inflating: /content/derain/TestData/input_100L/rain-024.png
#   inflating: /content/derain/TestData/input_100L/rain-025.png
#   inflating: /content/derain/TestData/input_100L/rain-026.png
#   inflating: /content/derain/TestData/input_100L/rain-027.png
#   inflating: /content/derain/TestData/input_100L/rain-028.png
#   inflating: /content/derain/TestData/input_100L/rain-029.png
#   inflating: /content/derain/TestData/input_100L/rain-030.png
#   inflating: /content/derain/TestData/input_100L/rain-031.png
#   inflating: /content/derain/TestData/input_100L/rain-032.png
#   inflating: /content/derain/TestData/input_100L/rain-033.png
#   inflating: /content/derain/TestData/input_100L/rain-034.png
#   inflating: /content/derain/TestData/input_100L/rain-035.png
#   inflating: /content/derain/TestData/input_100L/rain-036.png
#   inflating: /content/derain/TestData/input_100L/rain-037.png
#   inflating: /content/derain/TestData/input_100L/rain-038.png
#   inflating: /content/derain/TestData/input_100L/rain-039.png
#   inflating: /content/derain/TestData/input_100L/rain-040.png
#   inflating: /content/derain/TestData/input_100L/rain-041.png
#   inflating: /content/derain/TestData/input_100L/rain-042.png
#   inflating: /content/derain/TestData/input_100L/rain-043.png
#   inflating: /content/derain/TestData/input_100L/rain-044.png
#   inflating: /content/derain/TestData/input_100L/rain-045.png
#   inflating: /content/derain/TestData/input_100L/rain-046.png
#   inflating: /content/derain/TestData/input_100L/rain-047.png
#   inflating: /content/derain/TestData/input_100L/rain-048.png
#   inflating: /content/derain/TestData/input_100L/rain-049.png
#   inflating: /content/derain/TestData/input_100L/rain-050.png
#   inflating: /content/derain/TestData/input_100L/rain-051.png
#   inflating: /content/derain/TestData/input_100L/rain-052.png
#   inflating: /content/derain/TestData/input_100L/rain-053.png
#   inflating: /content/derain/TestData/input_100L/rain-054.png
#   inflating: /content/derain/TestData/input_100L/rain-055.png
#   inflating: /content/derain/TestData/input_100L/rain-056.png
#   inflating: /content/derain/TestData/input_100L/rain-057.png
#   inflating: /content/derain/TestData/input_100L/rain-058.png
#   inflating: /content/derain/TestData/input_100L/rain-059.png
#   inflating: /content/derain/TestData/input_100L/rain-060.png
#   inflating: /content/derain/TestData/input_100L/rain-061.png
#   inflating: /content/derain/TestData/input_100L/rain-062.png
#   inflating: /content/derain/TestData/input_100L/rain-063.png
#   inflating: /content/derain/TestData/input_100L/rain-064.png
#   inflating: /content/derain/TestData/input_100L/rain-065.png
#   inflating: /content/derain/TestData/input_100L/rain-066.png
#   inflating: /content/derain/TestData/input_100L/rain-067.png
#   inflating: /content/derain/TestData/input_100L/rain-068.png
#   inflating: /content/derain/TestData/input_100L/rain-069.png
#   inflating: /content/derain/TestData/input_100L/rain-070.png
#   inflating: /content/derain/TestData/input_100L/rain-071.png
#   inflating: /content/derain/TestData/input_100L/rain-072.png
#   inflating: /content/derain/TestData/input_100L/rain-073.png
#   inflating: /content/derain/TestData/input_100L/rain-074.png
#   inflating: /content/derain/TestData/input_100L/rain-075.png
#   inflating: /content/derain/TestData/input_100L/rain-076.png
#   inflating: /content/derain/TestData/input_100L/rain-077.png
#   inflating: /content/derain/TestData/input_100L/rain-078.png
#   inflating: /content/derain/TestData/input_100L/rain-079.png
#   inflating: /content/derain/TestData/input_100L/rain-080.png
#   inflating: /content/derain/TestData/input_100L/rain-081.png
#   inflating: /content/derain/TestData/input_100L/rain-082.png
#   inflating: /content/derain/TestData/input_100L/rain-083.png
#   inflating: /content/derain/TestData/input_100L/rain-084.png
#   inflating: /content/derain/TestData/input_100L/rain-085.png
#   inflating: /content/derain/TestData/input_100L/rain-086.png
#   inflating: /content/derain/TestData/input_100L/rain-087.png
#   inflating: /content/derain/TestData/input_100L/rain-088.png
#   inflating: /content/derain/TestData/input_100L/rain-089.png
#   inflating: /content/derain/TestData/input_100L/rain-090.png
#   inflating: /content/derain/TestData/input_100L/rain-091.png
#   inflating: /content/derain/TestData/input_100L/rain-092.png
#   inflating: /content/derain/TestData/input_100L/rain-093.png
#   inflating: /content/derain/TestData/input_100L/rain-094.png
#   inflating: /content/derain/TestData/input_100L/rain-095.png
#   inflating: /content/derain/TestData/input_100L/rain-096.png
#   inflating: /content/derain/TestData/input_100L/rain-097.png
#   inflating: /content/derain/TestData/input_100L/rain-098.png
#   inflating: /content/derain/TestData/input_100L/rain-099.png
#   inflating: /content/derain/TestData/input_100L/rain-100.png
#    creating: /content/derain/TestData/input_100H/
#   inflating: /content/derain/TestData/input_100H/rain-001.png
#   inflating: /content/derain/TestData/input_100H/rain-002.png
#   inflating: /content/derain/TestData/input_100H/rain-003.png
#   inflating: /content/derain/TestData/input_100H/rain-004.png
#   inflating: /content/derain/TestData/input_100H/rain-005.png
#   inflating: /content/derain/TestData/input_100H/rain-006.png
#   inflating: /content/derain/TestData/input_100H/rain-007.png
#   inflating: /content/derain/TestData/input_100H/rain-008.png
#   inflating: /content/derain/TestData/input_100H/rain-009.png
#   inflating: /content/derain/TestData/input_100H/rain-010.png
#   inflating: /content/derain/TestData/input_100H/rain-011.png
#   inflating: /content/derain/TestData/input_100H/rain-012.png
#   inflating: /content/derain/TestData/input_100H/rain-013.png
#   inflating: /content/derain/TestData/input_100H/rain-014.png
#   inflating: /content/derain/TestData/input_100H/rain-015.png
#   inflating: /content/derain/TestData/input_100H/rain-016.png
#   inflating: /content/derain/TestData/input_100H/rain-017.png
#   inflating: /content/derain/TestData/input_100H/rain-018.png
#   inflating: /content/derain/TestData/input_100H/rain-019.png
#   inflating: /content/derain/TestData/input_100H/rain-020.png
#   inflating: /content/derain/TestData/input_100H/rain-021.png
#   inflating: /content/derain/TestData/input_100H/rain-022.png
#   inflating: /content/derain/TestData/input_100H/rain-023.png
#   inflating: /content/derain/TestData/input_100H/rain-024.png
#   inflating: /content/derain/TestData/input_100H/rain-025.png
#   inflating: /content/derain/TestData/input_100H/rain-026.png
#   inflating: /content/derain/TestData/input_100H/rain-027.png
#   inflating: /content/derain/TestData/input_100H/rain-028.png
#   inflating: /content/derain/TestData/input_100H/rain-029.png
#   inflating: /content/derain/TestData/input_100H/rain-030.png
#   inflating: /content/derain/TestData/input_100H/rain-031.png
#   inflating: /content/derain/TestData/input_100H/rain-032.png
#   inflating: /content/derain/TestData/input_100H/rain-033.png
#   inflating: /content/derain/TestData/input_100H/rain-034.png
#   inflating: /content/derain/TestData/input_100H/rain-035.png
#   inflating: /content/derain/TestData/input_100H/rain-036.png
#   inflating: /content/derain/TestData/input_100H/rain-037.png
#   inflating: /content/derain/TestData/input_100H/rain-038.png
#   inflating: /content/derain/TestData/input_100H/rain-039.png
#   inflating: /content/derain/TestData/input_100H/rain-040.png
#   inflating: /content/derain/TestData/input_100H/rain-041.png
#   inflating: /content/derain/TestData/input_100H/rain-042.png
#   inflating: /content/derain/TestData/input_100H/rain-043.png
#   inflating: /content/derain/TestData/input_100H/rain-044.png
#   inflating: /content/derain/TestData/input_100H/rain-045.png
#   inflating: /content/derain/TestData/input_100H/rain-046.png
#   inflating: /content/derain/TestData/input_100H/rain-047.png
#   inflating: /content/derain/TestData/input_100H/rain-048.png
#   inflating: /content/derain/TestData/input_100H/rain-049.png
#   inflating: /content/derain/TestData/input_100H/rain-050.png
#   inflating: /content/derain/TestData/input_100H/rain-051.png
#   inflating: /content/derain/TestData/input_100H/rain-052.png
#   inflating: /content/derain/TestData/input_100H/rain-053.png
#   inflating: /content/derain/TestData/input_100H/rain-054.png
#   inflating: /content/derain/TestData/input_100H/rain-055.png
#   inflating: /content/derain/TestData/input_100H/rain-056.png
#   inflating: /content/derain/TestData/input_100H/rain-057.png
#   inflating: /content/derain/TestData/input_100H/rain-058.png
#   inflating: /content/derain/TestData/input_100H/rain-059.png
#   inflating: /content/derain/TestData/input_100H/rain-060.png
#   inflating: /content/derain/TestData/input_100H/rain-061.png
#   inflating: /content/derain/TestData/input_100H/rain-062.png
#   inflating: /content/derain/TestData/input_100H/rain-063.png
#   inflating: /content/derain/TestData/input_100H/rain-064.png
#   inflating: /content/derain/TestData/input_100H/rain-065.png
#   inflating: /content/derain/TestData/input_100H/rain-066.png
#   inflating: /content/derain/TestData/input_100H/rain-067.png
#   inflating: /content/derain/TestData/input_100H/rain-068.png
#   inflating: /content/derain/TestData/input_100H/rain-069.png
#   inflating: /content/derain/TestData/input_100H/rain-070.png
#   inflating: /content/derain/TestData/input_100H/rain-071.png
#   inflating: /content/derain/TestData/input_100H/rain-072.png
#   inflating: /content/derain/TestData/input_100H/rain-073.png
#   inflating: /content/derain/TestData/input_100H/rain-074.png
#   inflating: /content/derain/TestData/input_100H/rain-075.png
#   inflating: /content/derain/TestData/input_100H/rain-076.png
#   inflating: /content/derain/TestData/input_100H/rain-077.png
#   inflating: /content/derain/TestData/input_100H/rain-078.png
#   inflating: /content/derain/TestData/input_100H/rain-079.png
#   inflating: /content/derain/TestData/input_100H/rain-080.png
#   inflating: /content/derain/TestData/input_100H/rain-081.png
#   inflating: /content/derain/TestData/input_100H/rain-082.png
#   inflating: /content/derain/TestData/input_100H/rain-083.png
#   inflating: /content/derain/TestData/input_100H/rain-084.png
#   inflating: /content/derain/TestData/input_100H/rain-085.png
#   inflating: /content/derain/TestData/input_100H/rain-086.png
#   inflating: /content/derain/TestData/input_100H/rain-087.png
#   inflating: /content/derain/TestData/input_100H/rain-088.png
#   inflating: /content/derain/TestData/input_100H/rain-089.png
#   inflating: /content/derain/TestData/input_100H/rain-090.png
#   inflating: /content/derain/TestData/input_100H/rain-091.png
#   inflating: /content/derain/TestData/input_100H/rain-092.png
#   inflating: /content/derain/TestData/input_100H/rain-093.png
#   inflating: /content/derain/TestData/input_100H/rain-094.png
#   inflating: /content/derain/TestData/input_100H/rain-095.png
#   inflating: /content/derain/TestData/input_100H/rain-096.png
#   inflating: /content/derain/TestData/input_100H/rain-097.png
#   inflating: /content/derain/TestData/input_100H/rain-098.png
#   inflating: /content/derain/TestData/input_100H/rain-099.png
#   inflating: /content/derain/TestData/input_100H/rain-100.png
#    creating: /content/derain/TestData/input_1400/
#   inflating: /content/derain/TestData/input_1400/1000_11.jpg
#   inflating: /content/derain/TestData/input_1400/1000_13.jpg
#   inflating: /content/derain/TestData/input_1400/1000_3.jpg
#   inflating: /content/derain/TestData/input_1400/1000_5.jpg
#   inflating: /content/derain/TestData/input_1400/1000_6.jpg
#   inflating: /content/derain/TestData/input_1400/1000_9.jpg
#   inflating: /content/derain/TestData/input_1400/901_1.jpg
#   inflating: /content/derain/TestData/input_1400/901_10.jpg
#   inflating: /content/derain/TestData/input_1400/901_11.jpg
#   inflating: /content/derain/TestData/input_1400/901_12.jpg
#   inflating: /content/derain/TestData/input_1400/901_2.jpg
#   inflating: /content/derain/TestData/input_1400/901_3.jpg
#   inflating: /content/derain/TestData/input_1400/901_4.jpg
#   inflating: /content/derain/TestData/input_1400/901_7.jpg
#   inflating: /content/derain/TestData/input_1400/901_8.jpg
#   inflating: /content/derain/TestData/input_1400/901_9.jpg
#   inflating: /content/derain/TestData/input_1400/902_1.jpg
#   inflating: /content/derain/TestData/input_1400/902_10.jpg
#   inflating: /content/derain/TestData/input_1400/902_11.jpg
#   inflating: /content/derain/TestData/input_1400/902_12.jpg
#   inflating: /content/derain/TestData/input_1400/902_13.jpg
#   inflating: /content/derain/TestData/input_1400/902_2.jpg
#   inflating: /content/derain/TestData/input_1400/902_5.jpg
#   inflating: /content/derain/TestData/input_1400/902_7.jpg
#   inflating: /content/derain/TestData/input_1400/903_1.jpg
#   inflating: /content/derain/TestData/input_1400/903_10.jpg
#   inflating: /content/derain/TestData/input_1400/903_12.jpg
#   inflating: /content/derain/TestData/input_1400/903_4.jpg
#   inflating: /content/derain/TestData/input_1400/903_5.jpg
#   inflating: /content/derain/TestData/input_1400/903_7.jpg
#   inflating: /content/derain/TestData/input_1400/904_1.jpg
#   inflating: /content/derain/TestData/input_1400/904_10.jpg
#   inflating: /content/derain/TestData/input_1400/904_13.jpg
#   inflating: /content/derain/TestData/input_1400/904_14.jpg
#   inflating: /content/derain/TestData/input_1400/904_4.jpg
#   inflating: /content/derain/TestData/input_1400/904_8.jpg
#   inflating: /content/derain/TestData/input_1400/905_11.jpg
#   inflating: /content/derain/TestData/input_1400/905_12.jpg
#   inflating: /content/derain/TestData/input_1400/905_6.jpg
#   inflating: /content/derain/TestData/input_1400/905_7.jpg
#   inflating: /content/derain/TestData/input_1400/905_8.jpg
#   inflating: /content/derain/TestData/input_1400/906_1.jpg
#   inflating: /content/derain/TestData/input_1400/906_11.jpg
#   inflating: /content/derain/TestData/input_1400/906_12.jpg
#   inflating: /content/derain/TestData/input_1400/906_13.jpg
#   inflating: /content/derain/TestData/input_1400/906_2.jpg
#   inflating: /content/derain/TestData/input_1400/906_3.jpg
#   inflating: /content/derain/TestData/input_1400/906_4.jpg
#   inflating: /content/derain/TestData/input_1400/906_7.jpg
#   inflating: /content/derain/TestData/input_1400/907_1.jpg
#   inflating: /content/derain/TestData/input_1400/907_10.jpg
#   inflating: /content/derain/TestData/input_1400/907_11.jpg
#   inflating: /content/derain/TestData/input_1400/907_12.jpg
#   inflating: /content/derain/TestData/input_1400/907_13.jpg
#   inflating: /content/derain/TestData/input_1400/907_14.jpg
#   inflating: /content/derain/TestData/input_1400/907_6.jpg
#   inflating: /content/derain/TestData/input_1400/907_7.jpg
#   inflating: /content/derain/TestData/input_1400/907_9.jpg
#   inflating: /content/derain/TestData/input_1400/908_12.jpg
#   inflating: /content/derain/TestData/input_1400/908_13.jpg
#   inflating: /content/derain/TestData/input_1400/908_14.jpg
#   inflating: /content/derain/TestData/input_1400/908_2.jpg
#   inflating: /content/derain/TestData/input_1400/908_7.jpg
#   inflating: /content/derain/TestData/input_1400/908_8.jpg
#   inflating: /content/derain/TestData/input_1400/909_1.jpg
#   inflating: /content/derain/TestData/input_1400/909_11.jpg
#   inflating: /content/derain/TestData/input_1400/909_12.jpg
#   inflating: /content/derain/TestData/input_1400/909_13.jpg
#   inflating: /content/derain/TestData/input_1400/909_2.jpg
#   inflating: /content/derain/TestData/input_1400/909_3.jpg
#   inflating: /content/derain/TestData/input_1400/909_5.jpg
#   inflating: /content/derain/TestData/input_1400/909_6.jpg
#   inflating: /content/derain/TestData/input_1400/909_8.jpg
#   inflating: /content/derain/TestData/input_1400/909_9.jpg
#   inflating: /content/derain/TestData/input_1400/910_11.jpg
#   inflating: /content/derain/TestData/input_1400/910_12.jpg
#   inflating: /content/derain/TestData/input_1400/910_13.jpg
#   inflating: /content/derain/TestData/input_1400/910_4.jpg
#   inflating: /content/derain/TestData/input_1400/910_6.jpg
#   inflating: /content/derain/TestData/input_1400/910_8.jpg
#   inflating: /content/derain/TestData/input_1400/910_9.jpg
#   inflating: /content/derain/TestData/input_1400/911_1.jpg
#   inflating: /content/derain/TestData/input_1400/911_10.jpg
#   inflating: /content/derain/TestData/input_1400/911_12.jpg
#   inflating: /content/derain/TestData/input_1400/911_2.jpg
#   inflating: /content/derain/TestData/input_1400/911_8.jpg
#   inflating: /content/derain/TestData/input_1400/912_1.jpg
#   inflating: /content/derain/TestData/input_1400/912_10.jpg
#   inflating: /content/derain/TestData/input_1400/912_11.jpg
#   inflating: /content/derain/TestData/input_1400/912_12.jpg
#   inflating: /content/derain/TestData/input_1400/912_14.jpg
#   inflating: /content/derain/TestData/input_1400/912_2.jpg
#   inflating: /content/derain/TestData/input_1400/912_6.jpg
#   inflating: /content/derain/TestData/input_1400/913_11.jpg
#   inflating: /content/derain/TestData/input_1400/913_2.jpg
#   inflating: /content/derain/TestData/input_1400/913_3.jpg
#   inflating: /content/derain/TestData/input_1400/913_8.jpg
#   inflating: /content/derain/TestData/input_1400/914_1.jpg
#   inflating: /content/derain/TestData/input_1400/914_10.jpg
#   inflating: /content/derain/TestData/input_1400/914_11.jpg
#   inflating: /content/derain/TestData/input_1400/914_14.jpg
#   inflating: /content/derain/TestData/input_1400/914_2.jpg
#   inflating: /content/derain/TestData/input_1400/914_3.jpg
#   inflating: /content/derain/TestData/input_1400/914_4.jpg
#   inflating: /content/derain/TestData/input_1400/914_8.jpg
#   inflating: /content/derain/TestData/input_1400/915_1.jpg
#   inflating: /content/derain/TestData/input_1400/915_10.jpg
#   inflating: /content/derain/TestData/input_1400/915_11.jpg
#   inflating: /content/derain/TestData/input_1400/915_13.jpg
#   inflating: /content/derain/TestData/input_1400/915_14.jpg
#   inflating: /content/derain/TestData/input_1400/915_3.jpg
#   inflating: /content/derain/TestData/input_1400/915_5.jpg
#   inflating: /content/derain/TestData/input_1400/915_6.jpg
#   inflating: /content/derain/TestData/input_1400/915_8.jpg
#   inflating: /content/derain/TestData/input_1400/916_1.jpg
#   inflating: /content/derain/TestData/input_1400/916_12.jpg
#   inflating: /content/derain/TestData/input_1400/916_5.jpg
#   inflating: /content/derain/TestData/input_1400/916_6.jpg
#   inflating: /content/derain/TestData/input_1400/916_7.jpg
#   inflating: /content/derain/TestData/input_1400/917_1.jpg
#   inflating: /content/derain/TestData/input_1400/917_10.jpg
#   inflating: /content/derain/TestData/input_1400/917_12.jpg
#   inflating: /content/derain/TestData/input_1400/917_3.jpg
#   inflating: /content/derain/TestData/input_1400/917_6.jpg
#   inflating: /content/derain/TestData/input_1400/917_7.jpg
#   inflating: /content/derain/TestData/input_1400/918_12.jpg
#   inflating: /content/derain/TestData/input_1400/918_13.jpg
#   inflating: /content/derain/TestData/input_1400/918_2.jpg
#   inflating: /content/derain/TestData/input_1400/918_3.jpg
#   inflating: /content/derain/TestData/input_1400/918_4.jpg
#   inflating: /content/derain/TestData/input_1400/918_5.jpg
#   inflating: /content/derain/TestData/input_1400/918_7.jpg
#   inflating: /content/derain/TestData/input_1400/918_8.jpg
#   inflating: /content/derain/TestData/input_1400/919_10.jpg
#   inflating: /content/derain/TestData/input_1400/919_14.jpg
#   inflating: /content/derain/TestData/input_1400/919_2.jpg
#   inflating: /content/derain/TestData/input_1400/919_4.jpg
#   inflating: /content/derain/TestData/input_1400/919_8.jpg
#   inflating: /content/derain/TestData/input_1400/920_10.jpg
#   inflating: /content/derain/TestData/input_1400/920_11.jpg
#   inflating: /content/derain/TestData/input_1400/920_12.jpg
#   inflating: /content/derain/TestData/input_1400/920_13.jpg
#   inflating: /content/derain/TestData/input_1400/920_4.jpg
#   inflating: /content/derain/TestData/input_1400/920_7.jpg
#   inflating: /content/derain/TestData/input_1400/921_11.jpg
#   inflating: /content/derain/TestData/input_1400/921_5.jpg
#   inflating: /content/derain/TestData/input_1400/921_8.jpg
#   inflating: /content/derain/TestData/input_1400/921_9.jpg
#   inflating: /content/derain/TestData/input_1400/922_10.jpg
#   inflating: /content/derain/TestData/input_1400/922_11.jpg
#   inflating: /content/derain/TestData/input_1400/922_12.jpg
#   inflating: /content/derain/TestData/input_1400/922_14.jpg
#   inflating: /content/derain/TestData/input_1400/922_2.jpg
#   inflating: /content/derain/TestData/input_1400/922_5.jpg
#   inflating: /content/derain/TestData/input_1400/922_8.jpg
#   inflating: /content/derain/TestData/input_1400/923_11.jpg
#   inflating: /content/derain/TestData/input_1400/923_12.jpg
#   inflating: /content/derain/TestData/input_1400/923_13.jpg
#   inflating: /content/derain/TestData/input_1400/923_14.jpg
#   inflating: /content/derain/TestData/input_1400/923_2.jpg
#   inflating: /content/derain/TestData/input_1400/923_3.jpg
#   inflating: /content/derain/TestData/input_1400/923_6.jpg
#   inflating: /content/derain/TestData/input_1400/923_7.jpg
#   inflating: /content/derain/TestData/input_1400/924_3.jpg
#   inflating: /content/derain/TestData/input_1400/924_5.jpg
#   inflating: /content/derain/TestData/input_1400/924_6.jpg
#   inflating: /content/derain/TestData/input_1400/924_7.jpg
#   inflating: /content/derain/TestData/input_1400/924_8.jpg
#   inflating: /content/derain/TestData/input_1400/925_14.jpg
#   inflating: /content/derain/TestData/input_1400/925_2.jpg
#   inflating: /content/derain/TestData/input_1400/925_4.jpg
#   inflating: /content/derain/TestData/input_1400/925_5.jpg
#   inflating: /content/derain/TestData/input_1400/925_6.jpg
#   inflating: /content/derain/TestData/input_1400/926_1.jpg
#   inflating: /content/derain/TestData/input_1400/926_10.jpg
#   inflating: /content/derain/TestData/input_1400/926_12.jpg
#   inflating: /content/derain/TestData/input_1400/926_2.jpg
#   inflating: /content/derain/TestData/input_1400/926_3.jpg
#   inflating: /content/derain/TestData/input_1400/926_6.jpg
#   inflating: /content/derain/TestData/input_1400/927_1.jpg
#   inflating: /content/derain/TestData/input_1400/927_10.jpg
#   inflating: /content/derain/TestData/input_1400/927_11.jpg
#   inflating: /content/derain/TestData/input_1400/927_12.jpg
#   inflating: /content/derain/TestData/input_1400/927_13.jpg
#   inflating: /content/derain/TestData/input_1400/927_14.jpg
#   inflating: /content/derain/TestData/input_1400/927_3.jpg
#   inflating: /content/derain/TestData/input_1400/927_4.jpg
#   inflating: /content/derain/TestData/input_1400/927_5.jpg
#   inflating: /content/derain/TestData/input_1400/927_6.jpg
#   inflating: /content/derain/TestData/input_1400/928_10.jpg
#   inflating: /content/derain/TestData/input_1400/928_12.jpg
#   inflating: /content/derain/TestData/input_1400/928_13.jpg
#   inflating: /content/derain/TestData/input_1400/928_14.jpg
#   inflating: /content/derain/TestData/input_1400/928_2.jpg
#   inflating: /content/derain/TestData/input_1400/928_3.jpg
#   inflating: /content/derain/TestData/input_1400/928_5.jpg
#   inflating: /content/derain/TestData/input_1400/928_6.jpg
#   inflating: /content/derain/TestData/input_1400/928_7.jpg
#   inflating: /content/derain/TestData/input_1400/928_8.jpg
#   inflating: /content/derain/TestData/input_1400/929_1.jpg
#   inflating: /content/derain/TestData/input_1400/929_10.jpg
#   inflating: /content/derain/TestData/input_1400/929_13.jpg
#   inflating: /content/derain/TestData/input_1400/929_14.jpg
#   inflating: /content/derain/TestData/input_1400/929_4.jpg
#   inflating: /content/derain/TestData/input_1400/929_6.jpg
#   inflating: /content/derain/TestData/input_1400/929_9.jpg
#   inflating: /content/derain/TestData/input_1400/930_11.jpg
#   inflating: /content/derain/TestData/input_1400/930_13.jpg
#   inflating: /content/derain/TestData/input_1400/930_3.jpg
#   inflating: /content/derain/TestData/input_1400/930_4.jpg
#   inflating: /content/derain/TestData/input_1400/930_5.jpg
#   inflating: /content/derain/TestData/input_1400/930_9.jpg
#   inflating: /content/derain/TestData/input_1400/931_1.jpg
#   inflating: /content/derain/TestData/input_1400/931_12.jpg
#   inflating: /content/derain/TestData/input_1400/931_14.jpg
#   inflating: /content/derain/TestData/input_1400/931_2.jpg
#   inflating: /content/derain/TestData/input_1400/931_5.jpg
#   inflating: /content/derain/TestData/input_1400/931_7.jpg
#   inflating: /content/derain/TestData/input_1400/931_9.jpg
#   inflating: /content/derain/TestData/input_1400/932_1.jpg
#   inflating: /content/derain/TestData/input_1400/932_10.jpg
#   inflating: /content/derain/TestData/input_1400/932_11.jpg
#   inflating: /content/derain/TestData/input_1400/932_13.jpg
#   inflating: /content/derain/TestData/input_1400/932_14.jpg
#   inflating: /content/derain/TestData/input_1400/932_5.jpg
#   inflating: /content/derain/TestData/input_1400/932_6.jpg
#   inflating: /content/derain/TestData/input_1400/933_1.jpg
#   inflating: /content/derain/TestData/input_1400/933_12.jpg
#   inflating: /content/derain/TestData/input_1400/933_13.jpg
#   inflating: /content/derain/TestData/input_1400/933_14.jpg
#   inflating: /content/derain/TestData/input_1400/933_5.jpg
#   inflating: /content/derain/TestData/input_1400/933_6.jpg
#   inflating: /content/derain/TestData/input_1400/933_7.jpg
#   inflating: /content/derain/TestData/input_1400/934_10.jpg
#   inflating: /content/derain/TestData/input_1400/934_11.jpg
#   inflating: /content/derain/TestData/input_1400/934_2.jpg
#   inflating: /content/derain/TestData/input_1400/934_3.jpg
#   inflating: /content/derain/TestData/input_1400/934_4.jpg
#   inflating: /content/derain/TestData/input_1400/934_5.jpg
#   inflating: /content/derain/TestData/input_1400/934_7.jpg
#   inflating: /content/derain/TestData/input_1400/934_8.jpg
#   inflating: /content/derain/TestData/input_1400/935_10.jpg
#   inflating: /content/derain/TestData/input_1400/935_11.jpg
#   inflating: /content/derain/TestData/input_1400/935_13.jpg
#   inflating: /content/derain/TestData/input_1400/935_3.jpg
#   inflating: /content/derain/TestData/input_1400/935_4.jpg
#   inflating: /content/derain/TestData/input_1400/935_5.jpg
#   inflating: /content/derain/TestData/input_1400/935_7.jpg
#   inflating: /content/derain/TestData/input_1400/935_9.jpg
#   inflating: /content/derain/TestData/input_1400/936_1.jpg
#   inflating: /content/derain/TestData/input_1400/936_10.jpg
#   inflating: /content/derain/TestData/input_1400/936_11.jpg
#   inflating: /content/derain/TestData/input_1400/936_14.jpg
#   inflating: /content/derain/TestData/input_1400/936_2.jpg
#   inflating: /content/derain/TestData/input_1400/936_3.jpg
#   inflating: /content/derain/TestData/input_1400/936_4.jpg
#   inflating: /content/derain/TestData/input_1400/936_9.jpg
#   inflating: /content/derain/TestData/input_1400/937_1.jpg
#   inflating: /content/derain/TestData/input_1400/937_11.jpg
#   inflating: /content/derain/TestData/input_1400/937_13.jpg
#   inflating: /content/derain/TestData/input_1400/937_5.jpg
#   inflating: /content/derain/TestData/input_1400/937_6.jpg
#   inflating: /content/derain/TestData/input_1400/937_7.jpg
#   inflating: /content/derain/TestData/input_1400/937_8.jpg
#   inflating: /content/derain/TestData/input_1400/937_9.jpg
#   inflating: /content/derain/TestData/input_1400/938_1.jpg
#   inflating: /content/derain/TestData/input_1400/938_10.jpg
#   inflating: /content/derain/TestData/input_1400/938_13.jpg
#   inflating: /content/derain/TestData/input_1400/938_2.jpg
#   inflating: /content/derain/TestData/input_1400/938_3.jpg
#   inflating: /content/derain/TestData/input_1400/938_7.jpg
#   inflating: /content/derain/TestData/input_1400/938_8.jpg
#   inflating: /content/derain/TestData/input_1400/939_10.jpg
#   inflating: /content/derain/TestData/input_1400/939_11.jpg
#   inflating: /content/derain/TestData/input_1400/939_12.jpg
#   inflating: /content/derain/TestData/input_1400/939_14.jpg
#   inflating: /content/derain/TestData/input_1400/939_4.jpg
#   inflating: /content/derain/TestData/input_1400/939_7.jpg
#   inflating: /content/derain/TestData/input_1400/939_8.jpg
#   inflating: /content/derain/TestData/input_1400/939_9.jpg
#   inflating: /content/derain/TestData/input_1400/940_1.jpg
#   inflating: /content/derain/TestData/input_1400/940_10.jpg
#   inflating: /content/derain/TestData/input_1400/940_14.jpg
#   inflating: /content/derain/TestData/input_1400/940_2.jpg
#   inflating: /content/derain/TestData/input_1400/940_5.jpg
#   inflating: /content/derain/TestData/input_1400/940_8.jpg
#   inflating: /content/derain/TestData/input_1400/941_1.jpg
#   inflating: /content/derain/TestData/input_1400/941_10.jpg
#   inflating: /content/derain/TestData/input_1400/941_11.jpg
#   inflating: /content/derain/TestData/input_1400/941_2.jpg
#   inflating: /content/derain/TestData/input_1400/941_3.jpg
#   inflating: /content/derain/TestData/input_1400/941_4.jpg
#   inflating: /content/derain/TestData/input_1400/941_5.jpg
#   inflating: /content/derain/TestData/input_1400/941_7.jpg
#   inflating: /content/derain/TestData/input_1400/941_9.jpg
#   inflating: /content/derain/TestData/input_1400/942_1.jpg
#   inflating: /content/derain/TestData/input_1400/942_10.jpg
#   inflating: /content/derain/TestData/input_1400/942_13.jpg
#   inflating: /content/derain/TestData/input_1400/942_4.jpg
#   inflating: /content/derain/TestData/input_1400/942_5.jpg
#   inflating: /content/derain/TestData/input_1400/942_6.jpg
#   inflating: /content/derain/TestData/input_1400/942_7.jpg
#   inflating: /content/derain/TestData/input_1400/942_9.jpg
#   inflating: /content/derain/TestData/input_1400/943_1.jpg
#   inflating: /content/derain/TestData/input_1400/943_10.jpg
#   inflating: /content/derain/TestData/input_1400/943_6.jpg
#   inflating: /content/derain/TestData/input_1400/943_7.jpg
#   inflating: /content/derain/TestData/input_1400/944_12.jpg
#   inflating: /content/derain/TestData/input_1400/944_13.jpg
#   inflating: /content/derain/TestData/input_1400/944_14.jpg
#   inflating: /content/derain/TestData/input_1400/944_6.jpg
#   inflating: /content/derain/TestData/input_1400/944_8.jpg
#   inflating: /content/derain/TestData/input_1400/944_9.jpg
#   inflating: /content/derain/TestData/input_1400/945_11.jpg
#   inflating: /content/derain/TestData/input_1400/945_12.jpg
#   inflating: /content/derain/TestData/input_1400/945_13.jpg
#   inflating: /content/derain/TestData/input_1400/945_14.jpg
#   inflating: /content/derain/TestData/input_1400/945_2.jpg
#   inflating: /content/derain/TestData/input_1400/945_3.jpg
#   inflating: /content/derain/TestData/input_1400/945_4.jpg
#   inflating: /content/derain/TestData/input_1400/945_6.jpg
#   inflating: /content/derain/TestData/input_1400/946_10.jpg
#   inflating: /content/derain/TestData/input_1400/946_11.jpg
#   inflating: /content/derain/TestData/input_1400/946_14.jpg
#   inflating: /content/derain/TestData/input_1400/946_3.jpg
#   inflating: /content/derain/TestData/input_1400/946_5.jpg
#   inflating: /content/derain/TestData/input_1400/946_7.jpg
#   inflating: /content/derain/TestData/input_1400/946_8.jpg
#   inflating: /content/derain/TestData/input_1400/947_1.jpg
#   inflating: /content/derain/TestData/input_1400/947_10.jpg
#   inflating: /content/derain/TestData/input_1400/947_7.jpg
#   inflating: /content/derain/TestData/input_1400/947_8.jpg
#   inflating: /content/derain/TestData/input_1400/948_1.jpg
#   inflating: /content/derain/TestData/input_1400/948_10.jpg
#   inflating: /content/derain/TestData/input_1400/948_11.jpg
#   inflating: /content/derain/TestData/input_1400/948_13.jpg
#   inflating: /content/derain/TestData/input_1400/948_14.jpg
#   inflating: /content/derain/TestData/input_1400/948_2.jpg
#   inflating: /content/derain/TestData/input_1400/948_3.jpg
#   inflating: /content/derain/TestData/input_1400/948_4.jpg
#   inflating: /content/derain/TestData/input_1400/948_7.jpg
#   inflating: /content/derain/TestData/input_1400/948_8.jpg
#   inflating: /content/derain/TestData/input_1400/948_9.jpg
#   inflating: /content/derain/TestData/input_1400/949_10.jpg
#   inflating: /content/derain/TestData/input_1400/949_11.jpg
#   inflating: /content/derain/TestData/input_1400/949_13.jpg
#   inflating: /content/derain/TestData/input_1400/949_2.jpg
#   inflating: /content/derain/TestData/input_1400/949_3.jpg
#   inflating: /content/derain/TestData/input_1400/949_5.jpg
#   inflating: /content/derain/TestData/input_1400/949_6.jpg
#   inflating: /content/derain/TestData/input_1400/949_7.jpg
#   inflating: /content/derain/TestData/input_1400/949_9.jpg
#   inflating: /content/derain/TestData/input_1400/950_12.jpg
#   inflating: /content/derain/TestData/input_1400/950_14.jpg
#   inflating: /content/derain/TestData/input_1400/950_2.jpg
#   inflating: /content/derain/TestData/input_1400/950_3.jpg
#   inflating: /content/derain/TestData/input_1400/950_5.jpg
#   inflating: /content/derain/TestData/input_1400/950_8.jpg
#   inflating: /content/derain/TestData/input_1400/950_9.jpg
#   inflating: /content/derain/TestData/input_1400/951_10.jpg
#   inflating: /content/derain/TestData/input_1400/951_11.jpg
#   inflating: /content/derain/TestData/input_1400/951_12.jpg
#   inflating: /content/derain/TestData/input_1400/951_13.jpg
#   inflating: /content/derain/TestData/input_1400/951_14.jpg
#   inflating: /content/derain/TestData/input_1400/951_5.jpg
#   inflating: /content/derain/TestData/input_1400/951_7.jpg
#   inflating: /content/derain/TestData/input_1400/951_9.jpg
#   inflating: /content/derain/TestData/input_1400/952_1.jpg
#   inflating: /content/derain/TestData/input_1400/952_12.jpg
#   inflating: /content/derain/TestData/input_1400/952_14.jpg
#   inflating: /content/derain/TestData/input_1400/952_3.jpg
#   inflating: /content/derain/TestData/input_1400/952_4.jpg
#   inflating: /content/derain/TestData/input_1400/952_6.jpg
#   inflating: /content/derain/TestData/input_1400/952_7.jpg
#   inflating: /content/derain/TestData/input_1400/952_8.jpg
#   inflating: /content/derain/TestData/input_1400/952_9.jpg
#   inflating: /content/derain/TestData/input_1400/953_11.jpg
#   inflating: /content/derain/TestData/input_1400/953_12.jpg
#   inflating: /content/derain/TestData/input_1400/953_3.jpg
#   inflating: /content/derain/TestData/input_1400/953_4.jpg
#   inflating: /content/derain/TestData/input_1400/953_5.jpg
#   inflating: /content/derain/TestData/input_1400/953_6.jpg
#   inflating: /content/derain/TestData/input_1400/953_7.jpg
#   inflating: /content/derain/TestData/input_1400/953_9.jpg
#   inflating: /content/derain/TestData/input_1400/954_11.jpg
#   inflating: /content/derain/TestData/input_1400/954_12.jpg
#   inflating: /content/derain/TestData/input_1400/954_13.jpg
#   inflating: /content/derain/TestData/input_1400/954_14.jpg
#   inflating: /content/derain/TestData/input_1400/954_3.jpg
#   inflating: /content/derain/TestData/input_1400/954_7.jpg
#   inflating: /content/derain/TestData/input_1400/955_13.jpg
#   inflating: /content/derain/TestData/input_1400/955_14.jpg
#   inflating: /content/derain/TestData/input_1400/955_2.jpg
#   inflating: /content/derain/TestData/input_1400/955_4.jpg
#   inflating: /content/derain/TestData/input_1400/955_5.jpg
#   inflating: /content/derain/TestData/input_1400/955_9.jpg
#   inflating: /content/derain/TestData/input_1400/956_13.jpg
#   inflating: /content/derain/TestData/input_1400/956_14.jpg
#   inflating: /content/derain/TestData/input_1400/956_3.jpg
#   inflating: /content/derain/TestData/input_1400/956_4.jpg
#   inflating: /content/derain/TestData/input_1400/956_7.jpg
#   inflating: /content/derain/TestData/input_1400/957_10.jpg
#   inflating: /content/derain/TestData/input_1400/957_12.jpg
#   inflating: /content/derain/TestData/input_1400/957_13.jpg
#   inflating: /content/derain/TestData/input_1400/957_2.jpg
#   inflating: /content/derain/TestData/input_1400/957_6.jpg
#   inflating: /content/derain/TestData/input_1400/957_7.jpg
#   inflating: /content/derain/TestData/input_1400/957_8.jpg
#   inflating: /content/derain/TestData/input_1400/957_9.jpg
#   inflating: /content/derain/TestData/input_1400/958_1.jpg
#   inflating: /content/derain/TestData/input_1400/958_10.jpg
#   inflating: /content/derain/TestData/input_1400/958_12.jpg
#   inflating: /content/derain/TestData/input_1400/958_13.jpg
#   inflating: /content/derain/TestData/input_1400/958_3.jpg
#   inflating: /content/derain/TestData/input_1400/958_4.jpg
#   inflating: /content/derain/TestData/input_1400/958_5.jpg
#   inflating: /content/derain/TestData/input_1400/958_6.jpg
#   inflating: /content/derain/TestData/input_1400/958_7.jpg
#   inflating: /content/derain/TestData/input_1400/958_8.jpg
#   inflating: /content/derain/TestData/input_1400/958_9.jpg
#   inflating: /content/derain/TestData/input_1400/959_12.jpg
#   inflating: /content/derain/TestData/input_1400/959_13.jpg
#   inflating: /content/derain/TestData/input_1400/959_14.jpg
#   inflating: /content/derain/TestData/input_1400/959_5.jpg
#   inflating: /content/derain/TestData/input_1400/959_6.jpg
#   inflating: /content/derain/TestData/input_1400/960_1.jpg
#   inflating: /content/derain/TestData/input_1400/960_10.jpg
#   inflating: /content/derain/TestData/input_1400/960_11.jpg
#   inflating: /content/derain/TestData/input_1400/960_13.jpg
#   inflating: /content/derain/TestData/input_1400/961_10.jpg
#   inflating: /content/derain/TestData/input_1400/961_12.jpg
#   inflating: /content/derain/TestData/input_1400/961_13.jpg
#   inflating: /content/derain/TestData/input_1400/961_2.jpg
#   inflating: /content/derain/TestData/input_1400/961_6.jpg
#   inflating: /content/derain/TestData/input_1400/961_7.jpg
#   inflating: /content/derain/TestData/input_1400/961_8.jpg
#   inflating: /content/derain/TestData/input_1400/962_1.jpg
#   inflating: /content/derain/TestData/input_1400/962_10.jpg
#   inflating: /content/derain/TestData/input_1400/962_12.jpg
#   inflating: /content/derain/TestData/input_1400/962_13.jpg
#   inflating: /content/derain/TestData/input_1400/962_4.jpg
#   inflating: /content/derain/TestData/input_1400/962_5.jpg
#   inflating: /content/derain/TestData/input_1400/962_7.jpg
#   inflating: /content/derain/TestData/input_1400/962_8.jpg
#   inflating: /content/derain/TestData/input_1400/963_11.jpg
#   inflating: /content/derain/TestData/input_1400/963_13.jpg
#   inflating: /content/derain/TestData/input_1400/963_3.jpg
#   inflating: /content/derain/TestData/input_1400/963_4.jpg
#   inflating: /content/derain/TestData/input_1400/963_5.jpg
#   inflating: /content/derain/TestData/input_1400/963_6.jpg
#   inflating: /content/derain/TestData/input_1400/963_7.jpg
#   inflating: /content/derain/TestData/input_1400/964_10.jpg
#   inflating: /content/derain/TestData/input_1400/964_12.jpg
#   inflating: /content/derain/TestData/input_1400/964_13.jpg
#   inflating: /content/derain/TestData/input_1400/964_4.jpg
#   inflating: /content/derain/TestData/input_1400/964_5.jpg
#   inflating: /content/derain/TestData/input_1400/965_1.jpg
#   inflating: /content/derain/TestData/input_1400/965_10.jpg
#   inflating: /content/derain/TestData/input_1400/965_12.jpg
#   inflating: /content/derain/TestData/input_1400/965_13.jpg
#   inflating: /content/derain/TestData/input_1400/965_4.jpg
#   inflating: /content/derain/TestData/input_1400/965_5.jpg
#   inflating: /content/derain/TestData/input_1400/965_7.jpg
#   inflating: /content/derain/TestData/input_1400/965_8.jpg
#   inflating: /content/derain/TestData/input_1400/966_10.jpg
#   inflating: /content/derain/TestData/input_1400/966_12.jpg
#   inflating: /content/derain/TestData/input_1400/966_13.jpg
#   inflating: /content/derain/TestData/input_1400/966_14.jpg
#   inflating: /content/derain/TestData/input_1400/966_2.jpg
#   inflating: /content/derain/TestData/input_1400/966_5.jpg
#   inflating: /content/derain/TestData/input_1400/966_7.jpg
#   inflating: /content/derain/TestData/input_1400/967_1.jpg
#   inflating: /content/derain/TestData/input_1400/967_10.jpg
#   inflating: /content/derain/TestData/input_1400/967_11.jpg
#   inflating: /content/derain/TestData/input_1400/967_13.jpg
#   inflating: /content/derain/TestData/input_1400/967_14.jpg
#   inflating: /content/derain/TestData/input_1400/967_2.jpg
#   inflating: /content/derain/TestData/input_1400/967_3.jpg
#   inflating: /content/derain/TestData/input_1400/967_4.jpg
#   inflating: /content/derain/TestData/input_1400/967_7.jpg
#   inflating: /content/derain/TestData/input_1400/967_8.jpg
#   inflating: /content/derain/TestData/input_1400/968_1.jpg
#   inflating: /content/derain/TestData/input_1400/968_11.jpg
#   inflating: /content/derain/TestData/input_1400/968_3.jpg
#   inflating: /content/derain/TestData/input_1400/968_5.jpg
#   inflating: /content/derain/TestData/input_1400/968_6.jpg
#   inflating: /content/derain/TestData/input_1400/968_7.jpg
#   inflating: /content/derain/TestData/input_1400/968_8.jpg
#   inflating: /content/derain/TestData/input_1400/968_9.jpg
#   inflating: /content/derain/TestData/input_1400/969_1.jpg
#   inflating: /content/derain/TestData/input_1400/969_13.jpg
#   inflating: /content/derain/TestData/input_1400/969_2.jpg
#   inflating: /content/derain/TestData/input_1400/969_4.jpg
#   inflating: /content/derain/TestData/input_1400/969_5.jpg
#   inflating: /content/derain/TestData/input_1400/969_8.jpg
#   inflating: /content/derain/TestData/input_1400/969_9.jpg
#   inflating: /content/derain/TestData/input_1400/970_11.jpg
#   inflating: /content/derain/TestData/input_1400/970_12.jpg
#   inflating: /content/derain/TestData/input_1400/970_3.jpg
#   inflating: /content/derain/TestData/input_1400/970_4.jpg
#   inflating: /content/derain/TestData/input_1400/970_6.jpg
#   inflating: /content/derain/TestData/input_1400/970_8.jpg
#   inflating: /content/derain/TestData/input_1400/971_1.jpg
#   inflating: /content/derain/TestData/input_1400/971_10.jpg
#   inflating: /content/derain/TestData/input_1400/971_11.jpg
#   inflating: /content/derain/TestData/input_1400/971_12.jpg
#   inflating: /content/derain/TestData/input_1400/971_14.jpg
#   inflating: /content/derain/TestData/input_1400/971_2.jpg
#   inflating: /content/derain/TestData/input_1400/971_5.jpg
#   inflating: /content/derain/TestData/input_1400/971_6.jpg
#   inflating: /content/derain/TestData/input_1400/971_7.jpg
#   inflating: /content/derain/TestData/input_1400/971_8.jpg
#   inflating: /content/derain/TestData/input_1400/971_9.jpg
#   inflating: /content/derain/TestData/input_1400/972_1.jpg
#   inflating: /content/derain/TestData/input_1400/972_10.jpg
#   inflating: /content/derain/TestData/input_1400/972_11.jpg
#   inflating: /content/derain/TestData/input_1400/972_12.jpg
#   inflating: /content/derain/TestData/input_1400/972_13.jpg
#   inflating: /content/derain/TestData/input_1400/972_14.jpg
#   inflating: /content/derain/TestData/input_1400/972_2.jpg
#   inflating: /content/derain/TestData/input_1400/972_4.jpg
#   inflating: /content/derain/TestData/input_1400/972_6.jpg
#   inflating: /content/derain/TestData/input_1400/972_7.jpg
#   inflating: /content/derain/TestData/input_1400/972_8.jpg
#   inflating: /content/derain/TestData/input_1400/972_9.jpg
#   inflating: /content/derain/TestData/input_1400/973_1.jpg
#   inflating: /content/derain/TestData/input_1400/973_12.jpg
#   inflating: /content/derain/TestData/input_1400/973_13.jpg
#   inflating: /content/derain/TestData/input_1400/973_14.jpg
#   inflating: /content/derain/TestData/input_1400/973_9.jpg
#   inflating: /content/derain/TestData/input_1400/974_10.jpg
#   inflating: /content/derain/TestData/input_1400/974_12.jpg
#   inflating: /content/derain/TestData/input_1400/974_13.jpg
#   inflating: /content/derain/TestData/input_1400/974_14.jpg
#   inflating: /content/derain/TestData/input_1400/974_3.jpg
#   inflating: /content/derain/TestData/input_1400/974_5.jpg
#   inflating: /content/derain/TestData/input_1400/974_6.jpg
#   inflating: /content/derain/TestData/input_1400/974_7.jpg
#   inflating: /content/derain/TestData/input_1400/974_8.jpg
#   inflating: /content/derain/TestData/input_1400/974_9.jpg
#   inflating: /content/derain/TestData/input_1400/975_10.jpg
#   inflating: /content/derain/TestData/input_1400/975_12.jpg
#   inflating: /content/derain/TestData/input_1400/975_2.jpg
#   inflating: /content/derain/TestData/input_1400/975_4.jpg
#   inflating: /content/derain/TestData/input_1400/975_5.jpg
#   inflating: /content/derain/TestData/input_1400/975_6.jpg
#   inflating: /content/derain/TestData/input_1400/975_7.jpg
#   inflating: /content/derain/TestData/input_1400/975_8.jpg
#   inflating: /content/derain/TestData/input_1400/976_1.jpg
#   inflating: /content/derain/TestData/input_1400/976_11.jpg
#   inflating: /content/derain/TestData/input_1400/976_12.jpg
#   inflating: /content/derain/TestData/input_1400/976_13.jpg
#   inflating: /content/derain/TestData/input_1400/976_4.jpg
#   inflating: /content/derain/TestData/input_1400/976_7.jpg
#   inflating: /content/derain/TestData/input_1400/976_9.jpg
#   inflating: /content/derain/TestData/input_1400/977_11.jpg
#   inflating: /content/derain/TestData/input_1400/977_12.jpg
#   inflating: /content/derain/TestData/input_1400/977_13.jpg
#   inflating: /content/derain/TestData/input_1400/977_2.jpg
#   inflating: /content/derain/TestData/input_1400/977_6.jpg
#   inflating: /content/derain/TestData/input_1400/977_7.jpg
#   inflating: /content/derain/TestData/input_1400/977_8.jpg
#   inflating: /content/derain/TestData/input_1400/978_1.jpg
#   inflating: /content/derain/TestData/input_1400/978_11.jpg
#   inflating: /content/derain/TestData/input_1400/978_13.jpg
#   inflating: /content/derain/TestData/input_1400/978_2.jpg
#   inflating: /content/derain/TestData/input_1400/978_6.jpg
#   inflating: /content/derain/TestData/input_1400/978_8.jpg
#   inflating: /content/derain/TestData/input_1400/979_1.jpg
# ...
#   inflating: /content/derain/TestData/input_1400/986_3.jpg
#   inflating: /content/derain/TestData/input_1400/986_4.jpg
#   inflating: /content/derain/TestData/input_1400/987_10.jpg
#   inflating: /content/derain/TestData/input_1400/987_14.jpg
#   inflating: /content/derain/TestData/input_1400/989_9.jpg
#   inflating: /content/derain/TestData/input_1400/991_6.jpg
#   inflating: /content/derain/TestData/input_1400/991_8.jpg
#   inflating: /content/derain/TestData/input_1400/992_5.jpg
#   inflating: /content/derain/TestData/input_1400/993_12.jpg
#   inflating: /content/derain/TestData/input_1400/997_11.jpg
#   inflating: /content/derain/TestData/input_1400/997_6.jpg
#   inflating: /content/derain/TestData/input_1400/998_5.jpg
# Archive:  /content/Models.zip
#    creating: /content/derain/Models/
#    creating: /content/derain/Models/model_ddn/
#    creating: /content/derain/Models/model_ddn/trained/
#   inflating: /content/derain/Models/model_ddn/trained/model.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/trained/model.index
#    creating: /content/derain/Models/model_ddn/model_L/
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2100.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2000.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2000.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2200.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2100.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2300.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2200.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2400.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2300.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-2400.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118400.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118100.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118100.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118300.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118200.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118200.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118400.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118300.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118000.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-118000.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199600.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199700.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199800.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-199900.index
#   inflating: /content/derain/Models/model_ddn/model_L/model-epoch-200000.index
#   inflating: /content/derain/Models/model_ddn/model_L/checkpoint
#    creating: /content/derain/Models/model_ddn/model_H/
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199900.index
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-200000.index
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199600.index
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199700.index
#   inflating: /content/derain/Models/model_ddn/model_H/model-epoch-199800.index
#   inflating: /content/derain/Models/model_ddn/model_H/checkpoint
#    creating: /content/derain/Models/model_ddn/model_P/
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199900.index
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-200000.index
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199600.index
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199700.index
#   inflating: /content/derain/Models/model_ddn/model_P/model-epoch-199800.index
#   inflating: /content/derain/Models/model_ddn/model_P/checkpoint
#    creating: /content/derain/Models/model_derainnet/
#    creating: /content/derain/Models/model_derainnet/trained/
#   inflating: /content/derain/Models/model_derainnet/trained/model.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/trained/model.index
#    creating: /content/derain/Models/model_derainnet/model_P/
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4100.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4100.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4300.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4200.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4200.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4300.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-3900.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-200000.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4000.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-3900.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-100.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-100.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-300.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-200.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-200.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-400.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-300.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-400.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-4000.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199600.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199700.index
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199800.index
#   inflating: /content/derain/Models/model_derainnet/model_P/checkpoint
#   inflating: /content/derain/Models/model_derainnet/model_P/model-epoch-199900.index
#   inflating: /content/derain/Models/model_derainnet/model_P.zip
#    creating: /content/derain/Models/model_derainnet/model_L/
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199900.index
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-200000.index
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199600.index
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199700.index
#   inflating: /content/derain/Models/model_derainnet/model_L/model-epoch-199800.index
#   inflating: /content/derain/Models/model_derainnet/model_L/checkpoint
#    creating: /content/derain/Models/model_derainnet/model_H/
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199900.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199900.index
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-200000.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-200000.index
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199600.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199700.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199600.index
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199800.data-00000-of-00001
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199700.index
#   inflating: /content/derain/Models/model_derainnet/model_H/model-epoch-199800.index
#   inflating: /content/derain/Models/model_derainnet/model_H/checkpoint
#    creating: /content/derain/Models/models_effderain/
#   inflating: /content/derain/Models/models_effderain/.DS_Store
#    creating: /content/derain/Models/models_effderain/v3_SPA/
#   inflating: /content/derain/Models/models_effderain/v3_SPA/.DS_Store
#    creating: /content/derain/Models/models_effderain/v4_SPA/
#   inflating: /content/derain/Models/models_effderain/v4_SPA/.DS_Store
#    creating: /content/derain/Models/models_effderain/models_rain1400/
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch10_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch20_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch30_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch40_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch50_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain1400/KPN_rainy_image_epoch60_bs4.pth
#    creating: /content/derain/Models/models_effderain/models_rain100H/
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch5_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch10_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch15_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch20_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch50_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch100_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch150_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch200_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch250_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch300_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch350_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch400_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch450_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch500_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch550_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100H/KPN_rainy_image_epoch600_bs4.pth
#    creating: /content/derain/Models/models_effderain/models_rain100L/
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch200_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch400_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch600_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch800_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch1000_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch1200_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch1400_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch1600_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch1800_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch2000_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch2200_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch2400_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch2600_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch2800_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch3000_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch3200_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch3400_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch3600_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch3800_bs4.pth
#   inflating: /content/derain/Models/models_effderain/models_rain100L/KPN_rainy_image_epoch4000_bs4.pth

# %%
# !unzip '/content/derain/datasets/rain100H.zip' -d '/content/derain/datasets/'
# !unzip '/content/derain/datasets/rain100L.zip' -d '/content/derain/datasets/'
# !unzip '/content/derain/datasets/rain1400.zip' -d '/content/derain/datasets/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/18_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/190_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/190_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/191_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/191_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/192_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/194_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/194_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/195_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/196_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/197_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/19_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/201_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/204_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/207_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/207_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/209_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/20_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/20_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/210_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/211_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/211_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/211_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/213_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/214_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/214_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/215_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/215_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/217_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/217_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/21_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/21_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/220_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/220_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/222_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/224_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/225_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/226_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/227_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/229_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/229_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/231_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/232_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/232_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/233_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/234_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/234_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/235_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/235_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/235_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/236_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/237_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/23_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/23_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/23_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/23_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/240_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/240_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/241_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/242_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/242_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/243_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/244_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/247_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/248_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/249_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/249_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/250_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/250_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/250_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/251_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/251_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/252_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/253_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/253_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/254_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/258_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/259_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/259_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/25_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/25_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/260_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/260_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/260_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/261_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/262_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/262_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/266_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/266_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/267_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/26_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/271_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/271_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/272_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/273_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/275_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/276_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/276_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/276_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/277_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/278_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/278_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/278_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/279_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/280_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/282_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/285_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/285_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/286_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/286_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/288_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/289_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/289_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/289_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/28_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/290_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/291_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/291_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/294_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/294_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/295_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/297_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/297_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/298_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/299_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/299_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/29_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/2_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/300_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/302_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/302_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/302_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/303_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/303_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/306_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/309_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/309_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/310_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/312_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/313_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/313_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/314_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/315_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/315_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/315_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/316_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/316_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/318_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/318_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/319_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/31_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/31_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/320_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/321_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/322_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/322_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/323_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/323_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/324_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/325_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/325_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/325_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/326_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/327_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/327_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/328_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/329_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/32_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/330_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/330_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/331_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/334_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/335_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/335_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/336_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/338_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/338_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/339_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/339_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/33_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/340_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/340_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/341_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/342_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/342_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/344_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/344_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/345_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/345_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/346_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/346_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/348_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/348_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/348_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/348_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/349_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/34_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/34_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/34_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/351_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/351_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/351_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/355_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/356_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/358_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/359_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/359_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/359_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/361_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/361_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/363_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/363_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/365_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/366_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/366_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/366_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/368_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/369_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/369_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/36_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/370_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/372_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/372_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/373_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/373_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/374_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/375_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/375_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/376_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/377_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/378_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/378_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/37_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/37_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/382_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/383_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/383_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/384_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/384_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/385_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/386_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/388_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/389_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/390_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/391_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/392_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/392_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/393_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/393_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/393_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/394_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/396_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/396_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/396_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/398_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/3_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/3_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/3_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/403_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/403_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/403_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/404_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/405_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/405_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/405_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/406_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/407_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/407_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/407_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/408_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/40_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/40_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/40_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/411_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/411_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/413_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/414_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/414_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/415_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/417_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/418_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/418_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/419_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/420_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/422_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/422_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/423_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/425_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/426_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/427_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/427_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/429_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/42_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/42_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/431_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/431_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/432_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/432_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/434_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/436_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/436_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/436_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/437_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/439_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/439_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/440_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/441_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/446_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/446_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/446_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/447_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/447_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/448_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/449_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/449_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/450_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/450_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/452_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/453_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/453_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/453_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/456_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/456_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/457_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/457_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/459_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/45_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/460_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/460_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/461_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/461_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/461_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/462_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/462_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/462_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/464_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/465_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/467_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/468_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/469_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/46_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/46_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/471_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/474_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/474_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/475_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/476_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/477_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/478_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/478_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/478_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/478_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/479_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/482_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/483_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/483_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/484_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/484_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/484_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/487_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/487_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/487_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/488_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/488_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/488_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/489_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/489_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/48_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/48_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/48_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/48_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/490_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/490_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/491_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/492_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/493_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/493_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/495_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/496_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/496_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/497_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/498_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/49_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/49_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/49_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/500_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/501_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/502_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/503_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/503_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/503_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/504_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/505_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/505_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/507_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/508_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/511_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/512_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/514_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/515_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/515_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/516_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/516_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/517_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/518_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/519_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/519_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/522_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/523_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/523_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/523_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/525_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/525_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/527_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/528_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/52_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/52_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/531_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/532_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/532_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/532_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/533_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/535_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/535_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/536_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/536_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/537_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/537_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/538_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/540_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/541_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/542_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/545_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/546_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/547_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/549_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/549_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/54_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/54_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/550_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/550_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/551_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/554_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/556_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/556_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/557_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/55_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/55_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/55_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/560_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/561_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/562_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/563_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/563_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/564_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/564_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/567_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/567_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/567_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/568_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/569_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/569_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/570_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/572_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/573_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/575_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/575_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/576_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/576_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/577_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/579_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/57_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/57_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/581_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/582_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/582_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/585_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/587_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/588_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/588_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/588_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/589_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/589_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/590_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/592_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/592_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/594_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/595_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/597_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/598_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/599_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/599_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/5_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/5_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/604_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/605_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/606_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/606_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/607_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/607_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/607_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/609_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/610_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/611_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/612_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/613_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/614_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/616_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/617_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/619_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/61_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/620_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/621_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/622_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/622_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/623_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/624_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/626_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/626_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/627_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/627_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/628_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/628_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/629_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/629_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/62_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/62_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/62_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/631_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/631_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/632_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/636_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/637_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/639_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/639_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/639_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/63_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/640_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/640_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/643_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/644_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/645_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/646_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/647_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/64_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_11.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/650_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/652_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/655_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/656_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/657_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/658_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/658_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/658_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/65_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/661_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/662_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/663_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/664_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/664_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/666_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/667_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/667_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/668_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/668_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/669_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/669_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/66_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/670_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/670_5.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/670_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/670_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/671_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/672_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/672_10.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/673_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/674_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/675_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/675_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/676_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/677_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/677_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/678_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/678_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/679_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/67_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/680_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/682_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/682_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/683_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/683_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/686_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/687_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/687_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/688_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/689_4.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/68_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/68_14.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/691_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/692_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/692_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/692_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/693_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/696_13.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/696_6.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/697_2.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/698_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/699_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/6_3.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/700_9.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/702_12.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/704_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/704_7.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/704_8.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/705_1.jpg
#   inflating: /content/derain/datasets/rain1400/train/rainy_image/705_8.jpg
# ...
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/944_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/944_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/944_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/945_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/945_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/945_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/945_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/945_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/946_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/947_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/947_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/947_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/947_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/947_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/948_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/949_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/949_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/949_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/949_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/950_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/950_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/950_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/951_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/951_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/951_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/951_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/952_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/952_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/953_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/953_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/953_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/953_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/954_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/954_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/954_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/954_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/955_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/956_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/957_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/957_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/958_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/958_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/959_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/959_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/959_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/959_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/959_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/960_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/960_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/960_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/960_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/961_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/961_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/961_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/962_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/962_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/962_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/962_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/963_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/963_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/963_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/963_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/964_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/965_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/965_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/965_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/965_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/966_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/966_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/966_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/967_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/967_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/968_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/968_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/968_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/968_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/969_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/969_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/969_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/970_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/970_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/970_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/970_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/970_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/971_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/971_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/972_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/973_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/974_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/974_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/974_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/975_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/975_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/975_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/975_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/976_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/976_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/977_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/977_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/978_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/978_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/979_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/979_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/980_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/980_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/981_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/981_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/981_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/981_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/981_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/982_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/982_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/983_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/983_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/983_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/983_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/984_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/984_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/985_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/985_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/985_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/985_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/985_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/986_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/986_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/986_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/986_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/987_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/988_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/988_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/988_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/988_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/988_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/989_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/989_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/990_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/990_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/990_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_10.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_4.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/991_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/992_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/992_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/992_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/992_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/993_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/993_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/993_13.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/993_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/993_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/994_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/994_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/994_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/995_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/996_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/996_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/996_3.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/996_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/996_7.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/997_11.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/997_6.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/997_8.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/997_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/998_14.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/998_5.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/998_9.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/999_1.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/999_12.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/999_2.jpg
#   inflating: /content/derain/datasets/rain1400/test/rainy_image/999_6.jpg

# %% [markdown]
# Training

# %%
# ----------------------------------------
# Initialize the parameters
# ----------------------------------------
# Pre-train, saving, and loading parameters
save_path = './models'
sample_path = './samples'
save_mode = 'epoch'
save_by_epoch = 10
save_by_iter = 100000
load_name = ''

# GPU parameters
no_gpu = False
multi_gpu = False
gpu_ids = '0, 1, 2, 3'
cudnn_benchmark = True

# Training parameters
epochs = 100
train_batch_size = 16
lr_g = 0.0002
b1 = 0.5
b2 = 0.999
weight_decay = 0
lr_decrease_epoch = 20
num_workers = 8

# Initialization parameters
color = True
burst_length = 1
blind_est = True
kernel_size = [3]
sep_conv = False
channel_att = False
spatial_att = False
upMode = 'bilinear'
core_bias = False
init_type = 'xavier'
init_gain = 0.02

# Dataset parameters
baseroot = '/content/derain/datasets/rain100H/train/'
rainaug = False
crop_size = 256
geometry_aug = False
angle_aug = False
scale_min = 1
scale_max = 1
mu = 0
sigma = 30

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
from math import exp

def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size//2)**2/float(2*sigma**2)) for x in range(window_size)])
    return gauss/gauss.sum()

def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
    return window

def _ssim(img1, img2, window, window_size, channel, size_average = True):
    mu1 = F.conv2d(img1, window, padding = window_size//2, groups = channel)
    mu2 = F.conv2d(img2, window, padding = window_size//2, groups = channel)

    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1*mu2

    sigma1_sq = F.conv2d(img1*img1, window, padding = window_size//2, groups = channel) - mu1_sq
    sigma2_sq = F.conv2d(img2*img2, window, padding = window_size//2, groups = channel) - mu2_sq
    sigma12 = F.conv2d(img1*img2, window, padding = window_size//2, groups = channel) - mu1_mu2

    C1 = 0.01**2
    C2 = 0.03**2

    ssim_map = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*(sigma1_sq + sigma2_sq + C2))

    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

class SSIM(torch.nn.Module):
    def __init__(self, window_size = 11, size_average = True):
        super(SSIM, self).__init__()
        self.window_size = window_size
        self.size_average = size_average
        self.channel = 1
        self.window = create_window(window_size, self.channel)

    def forward(self, img1, img2):
        (_, channel, _, _) = img1.size()

        if channel == self.channel and self.window.data.type() == img1.data.type():
            window = self.window
        else:
            window = create_window(self.window_size, channel)

            if img1.is_cuda:
                window = window.cuda(img1.get_device())
            window = window.type_as(img1)

            self.window = window
            self.channel = channel


        return _ssim(img1, img2, window, self.window_size, channel, self.size_average)

def ssim(img1, img2, window_size = 11, size_average = True):
    (_, channel, _, _) = img1.size()
    window = create_window(window_size, channel)

    if img1.is_cuda:
        window = window.cuda(img1.get_device())
    window = window.type_as(img1)

    return _ssim(img1, img2, window, window_size, channel, size_average)

# %%
import time
import datetime
import os
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.autograd as autograd
from torch.utils.data import DataLoader
import torch.backends.cudnn as cudnn
from torchvision import transforms

def Pre_train():
    # ----------------------------------------
    #       Network training parameters
    # ----------------------------------------

    #torch.cuda.set_device(1)

    # cudnn benchmark
    cudnn.benchmark = cudnn_benchmark

    # configurations
    save_folder = save_path
    sample_folder = sample_path
    check_path(save_folder)
    check_path(sample_folder)

    # Loss functions
    if no_gpu == False:
        criterion_L1 = torch.nn.L1Loss().cuda()
        criterion_L2 = torch.nn.MSELoss().cuda()
        #criterion_rainypred = torch.nn.L1Loss().cuda()
        criterion_ssim = SSIM().cuda()
    else:
        criterion_L1 = torch.nn.L1Loss()
        criterion_L2 = torch.nn.MSELoss()
        #criterion_rainypred = torch.nn.L1Loss().cuda()
        criterion_ssim = SSIM()

    # Initialize Generator
    generator = create_generator()

    # To device
    if no_gpu == False:
        if multi_gpu:
            generator = nn.DataParallel(generator)
            generator = generator.cuda()
        else:
            generator = generator.cuda()

    # Optimizers
    optimizer_G = torch.optim.Adam(filter(lambda p: p.requires_grad, generator.parameters()), lr = lr_g, betas = (b1, b2), weight_decay = weight_decay)
    print("pretrained models loaded")

    # Learning rate decrease
    def adjust_learning_rate(epoch, optimizer):
        target_epoch = epochs - lr_decrease_epoch
        remain_epoch = epochs - epoch
        if epoch >= lr_decrease_epoch:
            lr = lr_g * remain_epoch / target_epoch
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr

    # Save the model if pre_train == True
    def save_model(epoch, iteration, len_dataset, generator):
        """Save the model at "checkpoint_interval" and its multiple"""
        # Define the name of trained model
        if save_mode == 'epoch':
            model_name = 'KPN_rainy_image_epoch%d_bs%d.pth' % (epoch, train_batch_size)
        if save_mode == 'iter':
            model_name = 'KPN_rainy_image_iter%d_bs%d.pth' % (iteration, train_batch_size)
        save_model_path = os.path.join(save_path, model_name)
        if multi_gpu == True:
            if save_mode == 'epoch':
                if (epoch % save_by_epoch == 0) and (iteration % len_dataset == 0):
                    torch.save(generator.module.state_dict(), save_model_path)
                    print('The trained model is successfully saved at epoch %d' % (epoch))
            if save_mode == 'iter':
                if iteration % save_by_iter == 0:
                    torch.save(generator.module.state_dict(), save_model_path)
                    print('The trained model is successfully saved at iteration %d' % (iteration))
        else:
            if save_mode == 'epoch':
                if (epoch % save_by_epoch == 0) and (iteration % len_dataset == 0):
                    torch.save(generator.state_dict(), save_model_path)
                    print('The trained model is successfully saved at epoch %d' % (epoch))
            if save_mode == 'iter':
                if iteration % save_by_iter == 0:
                    torch.save(generator.state_dict(), save_model_path)
                    print('The trained model is successfully saved at iteration %d' % (iteration))

    # ----------------------------------------
    #             Network dataset
    # ----------------------------------------

    # Handle multiple GPUs
    #os.environ["CUDA_VISIBLE_DEVICES"] = ""
    gpu_num = torch.cuda.device_count()
    print("There are %d GPUs used" % gpu_num)

    #print(opt.multi_gpu)
    '''
    print(opt.no_gpu == False)
    print(opt.no_gpu)
    print(gpu_num)
    print(opt.train_batch_size)
    '''

    # Define the dataset
    trainset = DenoisingDataset()
    print('The overall number of training images:', len(trainset))

    # Define the dataloader
    train_loader = DataLoader(trainset, batch_size = train_batch_size, shuffle = True, num_workers = num_workers, pin_memory = True)

    # ----------------------------------------
    #                 Training
    # ----------------------------------------

    # Count start time
    prev_time = time.time()

    # For loop training
    for epoch in range(epochs):
        for i, (true_input, true_target) in enumerate(train_loader):

            #print("in epoch %d" % i)

            if no_gpu == False:
                # To device
                true_input = true_input.cuda()
                true_target = true_target.cuda()

            # Train Generator
            optimizer_G.zero_grad()
            fake_target = generator(true_input, true_input)


            ssim_loss = -criterion_ssim(true_target, fake_target)

            # L1 Loss
            Pixellevel_L1_Loss = criterion_L1(fake_target, true_target)

            # Overall Loss and optimize
            loss = Pixellevel_L1_Loss + 0.2*ssim_loss
            #loss = Pixellevel_L1_Loss
            #loss = Pixellevel_L1_Loss + Pixellevel_L2_Loss + Loss_rainypred
            loss.backward()
            optimizer_G.step()

            # Determine approximate time left
            iters_done = epoch * len(train_loader) + i
            iters_left = epochs * len(train_loader) - iters_done
            time_left = datetime.timedelta(seconds = iters_left * (time.time() - prev_time))
            prev_time = time.time()

            # Print log
            print("\r[Iter %d] [Epoch %d/%d] [Batch %d/%d] [Loss: %.4f %.4f] Time_left: %s" %
                ((iters_done + 1), (epoch + 1), epochs, i, len(train_loader), Pixellevel_L1_Loss.item(), ssim_loss.item(), time_left))


            # Save model at certain epochs or iterations
            save_model((epoch + 1), (iters_done + 1), len(train_loader), generator)

            # Learning rate decrease at certain epochs
            adjust_learning_rate((epoch + 1), optimizer_G)

        ### Sample data every epoch
        if (epoch + 1) % 1 == 0:
            img_list = [true_input, fake_target, true_target]
            name_list = ['in', 'pred', 'gt']
            save_sample_png(sample_folder = sample_folder, sample_name = 'train_epoch%d' % (epoch + 1), img_list = img_list, name_list = name_list, pixel_max_cnt = 255)

# %%
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"

def str2bool(v):
    #print(v)
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Unsupported value encountered.')

if __name__ == "__main__":
    Pre_train()
# Out:
# initialize network with xavier type
# Generator is created!
# pretrained models loaded
# There are 1 GPUs used
# The overall number of training images: 1254
# [Iter 1] [Epoch 1/100] [Batch 0/79] [Loss: 0.3705 -0.0193] Time_left: 5:40:27.410746
# [Iter 2] [Epoch 1/100] [Batch 1/79] [Loss: 0.4111 -0.0308] Time_left: 0:54:58.629273
# [Iter 3] [Epoch 1/100] [Batch 2/79] [Loss: 0.4061 -0.0443] Time_left: 1:22:43.397643
# [Iter 4] [Epoch 1/100] [Batch 3/79] [Loss: 0.4340 -0.0497] Time_left: 1:27:54.540653
# [Iter 5] [Epoch 1/100] [Batch 4/79] [Loss: 0.3461 -0.0873] Time_left: 1:28:18.601954
# [Iter 6] [Epoch 1/100] [Batch 5/79] [Loss: 0.3750 -0.0736] Time_left: 1:28:18.486187
# [Iter 7] [Epoch 1/100] [Batch 6/79] [Loss: 0.3893 -0.0976] Time_left: 1:30:48.569377
# [Iter 8] [Epoch 1/100] [Batch 7/79] [Loss: 0.4184 -0.1132] Time_left: 1:29:32.383590
# [Iter 9] [Epoch 1/100] [Batch 8/79] [Loss: 0.3570 -0.1160] Time_left: 1:28:44.933903
# [Iter 10] [Epoch 1/100] [Batch 9/79] [Loss: 0.3234 -0.1486] Time_left: 1:27:28.207040
# [Iter 11] [Epoch 1/100] [Batch 10/79] [Loss: 0.3463 -0.1596] Time_left: 1:29:55.804510
# [Iter 12] [Epoch 1/100] [Batch 11/79] [Loss: 0.3040 -0.1749] Time_left: 1:29:23.271620
# [Iter 13] [Epoch 1/100] [Batch 12/79] [Loss: 0.3242 -0.1647] Time_left: 1:27:55.969234
# [Iter 14] [Epoch 1/100] [Batch 13/79] [Loss: 0.3569 -0.1934] Time_left: 1:29:31.729543
# [Iter 15] [Epoch 1/100] [Batch 14/79] [Loss: 0.1848 -0.3593] Time_left: 1:32:07.023509
# [Iter 16] [Epoch 1/100] [Batch 15/79] [Loss: 23.8219 -0.0021] Time_left: 1:28:34.240165
# [Iter 17] [Epoch 1/100] [Batch 16/79] [Loss: 0.1801 -0.3312] Time_left: 1:32:03.279682
# [Iter 18] [Epoch 1/100] [Batch 17/79] [Loss: 0.2652 -0.2618] Time_left: 1:31:55.668363
# [Iter 19] [Epoch 1/100] [Batch 18/79] [Loss: 0.3033 -0.1952] Time_left: 1:30:37.242450
# [Iter 20] [Epoch 1/100] [Batch 19/79] [Loss: 0.3348 -0.2263] Time_left: 1:30:43.431554
# [Iter 21] [Epoch 1/100] [Batch 20/79] [Loss: 0.3422 -0.1860] Time_left: 1:30:43.541193
# [Iter 22] [Epoch 1/100] [Batch 21/79] [Loss: 0.3232 -0.2022] Time_left: 1:30:34.470400
# [Iter 23] [Epoch 1/100] [Batch 22/79] [Loss: 0.2928 -0.1858] Time_left: 1:30:16.511922
# [Iter 24] [Epoch 1/100] [Batch 23/79] [Loss: 0.3551 -0.1684] Time_left: 1:30:33.318158
# [Iter 25] [Epoch 1/100] [Batch 24/79] [Loss: 0.2875 -0.2623] Time_left: 1:30:20.567377
# [Iter 26] [Epoch 1/100] [Batch 25/79] [Loss: 0.3020 -0.2275] Time_left: 1:31:50.996461
# [Iter 27] [Epoch 1/100] [Batch 26/79] [Loss: 0.2963 -0.2682] Time_left: 1:31:12.727966
# [Iter 28] [Epoch 1/100] [Batch 27/79] [Loss: 0.2892 -0.2835] Time_left: 1:31:37.840757
# [Iter 29] [Epoch 1/100] [Batch 28/79] [Loss: 0.2563 -0.3151] Time_left: 1:32:57.979431
# [Iter 30] [Epoch 1/100] [Batch 29/79] [Loss: 0.1801 -0.3787] Time_left: 1:30:54.556701
# [Iter 31] [Epoch 1/100] [Batch 30/79] [Loss: 0.2351 -0.4096] Time_left: 1:31:50.803552
# [Iter 32] [Epoch 1/100] [Batch 31/79] [Loss: 0.1892 -0.3230] Time_left: 1:33:52.416692
# [Iter 33] [Epoch 1/100] [Batch 32/79] [Loss: 0.1895 -0.3614] Time_left: 1:30:11.105243
# [Iter 34] [Epoch 1/100] [Batch 33/79] [Loss: 0.2008 -0.4044] Time_left: 1:34:04.334069
# [Iter 35] [Epoch 1/100] [Batch 34/79] [Loss: 0.1481 -0.3899] Time_left: 1:34:15.409118
# [Iter 36] [Epoch 1/100] [Batch 35/79] [Loss: 0.1789 -0.3247] Time_left: 1:31:05.752563
# [Iter 37] [Epoch 1/100] [Batch 36/79] [Loss: 0.1321 -0.3855] Time_left: 1:33:08.056362
# [Iter 38] [Epoch 1/100] [Batch 37/79] [Loss: 0.1683 -0.3896] Time_left: 1:30:14.334819
# [Iter 39] [Epoch 1/100] [Batch 38/79] [Loss: 0.1407 -0.3917] Time_left: 1:32:40.336699
# [Iter 40] [Epoch 1/100] [Batch 39/79] [Loss: 0.1660 -0.3927] Time_left: 1:33:54.020538
# [Iter 41] [Epoch 1/100] [Batch 40/79] [Loss: 0.1547 -0.3937] Time_left: 1:34:20.482020
# [Iter 42] [Epoch 1/100] [Batch 41/79] [Loss: 0.1461 -0.3714] Time_left: 1:31:50.129398
# [Iter 43] [Epoch 1/100] [Batch 42/79] [Loss: 0.1507 -0.3777] Time_left: 1:32:43.234999
# [Iter 44] [Epoch 1/100] [Batch 43/79] [Loss: 0.1477 -0.3821] Time_left: 1:32:50.227979
# [Iter 45] [Epoch 1/100] [Batch 44/79] [Loss: 0.1546 -0.4100] Time_left: 1:33:58.925522
# [Iter 46] [Epoch 1/100] [Batch 45/79] [Loss: 0.1653 -0.3909] Time_left: 1:33:32.103084
# [Iter 47] [Epoch 1/100] [Batch 46/79] [Loss: 0.1540 -0.4416] Time_left: 1:33:22.866694
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c66aa822304f> in <cell line: 12>()
#      11
#      12 if __name__ == "__main__":
# ---> 13     Pre_train()
#
# <ipython-input-31-d0c17b0ab152> in Pre_train()
#     158             # Print log
#     159             print("\r[Iter %d] [Epoch %d/%d] [Batch %d/%d] [Loss: %.4f %.4f] Time_left: %s" %
# --> 160                 ((iters_done + 1), (epoch + 1), epochs, i, len(train_loader), Pixellevel_L1_Loss.item(), ssim_loss.item(), time_left))
#     161
#     162
#
# KeyboardInterrupt:

# %% [markdown]
# Testing

# %%
import argparse
import os
import torch
import numpy as np
import cv2
from skimage.metrics import structural_similarity
import time


def str2bool(v):
    #print(v)
    if v.lower() in ('yes', 'true', 't', 'y', '1'):
        return True
    elif v.lower() in ('no', 'false', 'f', 'n', '0'):
        return False
    else:
        raise argparse.ArgumentTypeError('Unsupported value encountered.')

if __name__ == "__main__":

    if no_gpu:
        generator = create_generator()
    else:
        generator = create_generator().cuda()

    test_dataset = DenoisingValDataset()
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = test_batch_size, shuffle = False, num_workers = num_workers, pin_memory = True)
    sample_folder = save_name
    check_path(sample_folder)

    psnr_sum, psnr_ave, ssim_sum, ssim_ave, eval_cnt = 0, 0, 0, 0, 0
    time_test = 0
    count = 0
    # forward
    for i, (true_input, true_target, height_origin, width_origin) in enumerate(test_loader):

        # To device
        if no_gpu:
            true_input = true_input
            true_target = true_target
        else:
            true_input = true_input.cuda()
            true_target = true_target.cuda()

        # Forward propagation
        start_time = time.time()

        with torch.no_grad():
            #print(true_input.size())
            fake_target = generator(true_input, true_input)

        end_time = time.time()
        dur_time = end_time - start_time
        time_test += dur_time
        count += 1
        #print(fake_target.shape, true_input.shape)

        # Save
        print('The %d-th iteration' % (i))
        img_list = [true_input, fake_target, true_target]
        name_list = ['in', 'pred', 'gt']
        sample_name = '%d' % (i+1)
        save_sample_png(sample_folder = sample_folder, sample_name = '%d' % (i + 1), img_list = img_list, name_list = name_list, pixel_max_cnt = 255, height = image_height, width = image_width)

        # Evaluation
        #psnr_sum = psnr_sum + utils.psnr(cv2.imread(sample_folder + '/' + sample_name + '_' + name_list[1] + '.png').astype(np.float32), cv2.imread(sample_folder + '/' + sample_name + '_' + name_list[2] + '.png').astype(np.float32))
        img_pred_recover = recover_process(fake_target, height = image_height, width = image_width)
        img_gt_recover = recover_process(true_target, height = image_height, width = image_width)
        #psnr_sum = psnr_sum + utils.psnr(utils.recover_process(fake_target, height = height_origin, width = width_origin), utils.recover_process(true_target, height = height_origin, width = width_origin))
        psnr_sum = psnr_sum + psnr(img_pred_recover, img_gt_recover)
        ssim_sum = ssim_sum + structural_similarity(img_gt_recover, img_pred_recover, multichannel = True, data_range = 255)
        eval_cnt = eval_cnt + 1

    print('Avg. time:', time_test/count)
# Out:
# Generator is loaded!
# The 0-th iteration
# <ipython-input-18-60ffd08acd70>:71: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_sum = ssim_sum + structural_similarity(img_gt_recover, img_pred_recover, multichannel = True, data_range = 255)
# The 1-th iteration
# The 2-th iteration
# The 3-th iteration
# The 4-th iteration
# The 5-th iteration
# The 6-th iteration
# The 7-th iteration
# The 8-th iteration
# The 9-th iteration
# The 10-th iteration
# The 11-th iteration
# The 12-th iteration
# The 13-th iteration
# The 14-th iteration
# The 15-th iteration
# The 16-th iteration
# The 17-th iteration
# The 18-th iteration
# The 19-th iteration
# The 20-th iteration
# The 21-th iteration
# The 22-th iteration
# The 23-th iteration
# The 24-th iteration
# The 25-th iteration
# The 26-th iteration
# The 27-th iteration
# The 28-th iteration
# The 29-th iteration
# The 30-th iteration
# The 31-th iteration
# The 32-th iteration
# The 33-th iteration
# The 34-th iteration
# The 35-th iteration
# The 36-th iteration
# The 37-th iteration
# The 38-th iteration
# The 39-th iteration
# The 40-th iteration
# The 41-th iteration
# The 42-th iteration
# The 43-th iteration
# The 44-th iteration
# The 45-th iteration
# The 46-th iteration
# The 47-th iteration
# The 48-th iteration
# The 49-th iteration
# The 50-th iteration
# The 51-th iteration
# The 52-th iteration
# The 53-th iteration
# The 54-th iteration
# The 55-th iteration
# The 56-th iteration
# The 57-th iteration
# The 58-th iteration
# The 59-th iteration
# The 60-th iteration
# The 61-th iteration
# The 62-th iteration
# The 63-th iteration
# The 64-th iteration
# The 65-th iteration
# The 66-th iteration
# The 67-th iteration
# The 68-th iteration
# The 69-th iteration
# The 70-th iteration
# The 71-th iteration
# The 72-th iteration
# The 73-th iteration
# The 74-th iteration
# The 75-th iteration
# The 76-th iteration
# The 77-th iteration
# The 78-th iteration
# The 79-th iteration
# The 80-th iteration
# The 81-th iteration
# The 82-th iteration
# The 83-th iteration
# The 84-th iteration
# The 85-th iteration
# The 86-th iteration
# The 87-th iteration
# The 88-th iteration
# The 89-th iteration
# The 90-th iteration
# The 91-th iteration
# The 92-th iteration
# The 93-th iteration
# The 94-th iteration
# The 95-th iteration
# The 96-th iteration
# The 97-th iteration
# The 98-th iteration
# The 99-th iteration
# The 100-th iteration
# The 101-th iteration
# The 102-th iteration
# The 103-th iteration
# The 104-th iteration
# The 105-th iteration
# The 106-th iteration
# The 107-th iteration
# The 108-th iteration
# The 109-th iteration
# The 110-th iteration
# The 111-th iteration
# The 112-th iteration
# The 113-th iteration
# The 114-th iteration
# The 115-th iteration
# The 116-th iteration
# The 117-th iteration
# The 118-th iteration
# The 119-th iteration
# The 120-th iteration
# The 121-th iteration
# The 122-th iteration
# The 123-th iteration
# The 124-th iteration
# The 125-th iteration
# The 126-th iteration
# The 127-th iteration
# The 128-th iteration
# The 129-th iteration
# The 130-th iteration
# The 131-th iteration
# The 132-th iteration
# The 133-th iteration
# The 134-th iteration
# The 135-th iteration
# The 136-th iteration
# The 137-th iteration
# The 138-th iteration
# The 139-th iteration
# The 140-th iteration
# The 141-th iteration
# The 142-th iteration
# The 143-th iteration
# The 144-th iteration
# The 145-th iteration
# The 146-th iteration
# The 147-th iteration
# The 148-th iteration
# The 149-th iteration
# The 150-th iteration
# The 151-th iteration
# The 152-th iteration
# The 153-th iteration
# The 154-th iteration
# The 155-th iteration
# The 156-th iteration
# The 157-th iteration
# The 158-th iteration
# The 159-th iteration
# The 160-th iteration
# The 161-th iteration
# The 162-th iteration
# The 163-th iteration
# The 164-th iteration
# The 165-th iteration
# The 166-th iteration
# The 167-th iteration
# The 168-th iteration
# The 169-th iteration
# The 170-th iteration
# The 171-th iteration
# The 172-th iteration
# The 173-th iteration
# The 174-th iteration
# The 175-th iteration
# The 176-th iteration
# The 177-th iteration
# The 178-th iteration
# The 179-th iteration
# The 180-th iteration
# The 181-th iteration
# The 182-th iteration
# The 183-th iteration
# The 184-th iteration
# The 185-th iteration
# The 186-th iteration
# The 187-th iteration
# The 188-th iteration
# The 189-th iteration
# The 190-th iteration
# The 191-th iteration
# The 192-th iteration
# The 193-th iteration
# The 194-th iteration
# The 195-th iteration
# The 196-th iteration
# The 197-th iteration
# The 198-th iteration
# The 199-th iteration
# The 200-th iteration
# The 201-th iteration
# The 202-th iteration
# The 203-th iteration
# The 204-th iteration
# The 205-th iteration
# The 206-th iteration
# The 207-th iteration
# The 208-th iteration
# The 209-th iteration
# The 210-th iteration
# The 211-th iteration
# The 212-th iteration
# The 213-th iteration
# The 214-th iteration
# The 215-th iteration
# The 216-th iteration
# The 217-th iteration
# The 218-th iteration
# The 219-th iteration
# The 220-th iteration
# The 221-th iteration
# The 222-th iteration
# The 223-th iteration
# The 224-th iteration
# The 225-th iteration
# The 226-th iteration
# The 227-th iteration
# The 228-th iteration
# The 229-th iteration
# The 230-th iteration
# The 231-th iteration
# The 232-th iteration
# The 233-th iteration
# The 234-th iteration
# The 235-th iteration
# The 236-th iteration
# The 237-th iteration
# The 238-th iteration
# The 239-th iteration
# The 240-th iteration
# The 241-th iteration
# The 242-th iteration
# The 243-th iteration
# The 244-th iteration
# The 245-th iteration
# The 246-th iteration
# The 247-th iteration
# The 248-th iteration
# The 249-th iteration
# The 250-th iteration
# The 251-th iteration
# The 252-th iteration
# The 253-th iteration
# The 254-th iteration
# The 255-th iteration
# The 256-th iteration
# The 257-th iteration
# The 258-th iteration
# The 259-th iteration
# The 260-th iteration
# The 261-th iteration
# The 262-th iteration
# The 263-th iteration
# The 264-th iteration
# The 265-th iteration
# The 266-th iteration
# The 267-th iteration
# The 268-th iteration
# The 269-th iteration
# The 270-th iteration
# The 271-th iteration
# The 272-th iteration
# The 273-th iteration
# The 274-th iteration
# The 275-th iteration
# The 276-th iteration
# The 277-th iteration
# The 278-th iteration
# The 279-th iteration
# The 280-th iteration
# The 281-th iteration
# The 282-th iteration
# The 283-th iteration
# The 284-th iteration
# The 285-th iteration
# The 286-th iteration
# The 287-th iteration
# The 288-th iteration
# The 289-th iteration
# The 290-th iteration
# The 291-th iteration
# The 292-th iteration
# The 293-th iteration
# The 294-th iteration
# The 295-th iteration
# The 296-th iteration
# The 297-th iteration
# The 298-th iteration
# The 299-th iteration
# The 300-th iteration
# The 301-th iteration
# The 302-th iteration
# The 303-th iteration
# The 304-th iteration
# The 305-th iteration
# The 306-th iteration
# The 307-th iteration
# The 308-th iteration
# The 309-th iteration
# The 310-th iteration
# The 311-th iteration
# The 312-th iteration
# The 313-th iteration
# The 314-th iteration
# The 315-th iteration
# The 316-th iteration
# The 317-th iteration
# The 318-th iteration
# The 319-th iteration
# The 320-th iteration
# The 321-th iteration
# The 322-th iteration
# The 323-th iteration
# The 324-th iteration
# The 325-th iteration
# The 326-th iteration
# The 327-th iteration
# The 328-th iteration
# The 329-th iteration
# The 330-th iteration
# The 331-th iteration
# The 332-th iteration
# The 333-th iteration
# The 334-th iteration
# The 335-th iteration
# The 336-th iteration
# The 337-th iteration
# The 338-th iteration
# The 339-th iteration
# The 340-th iteration
# The 341-th iteration
# The 342-th iteration
# The 343-th iteration
# The 344-th iteration
# The 345-th iteration
# The 346-th iteration
# The 347-th iteration
# The 348-th iteration
# The 349-th iteration
# The 350-th iteration
# The 351-th iteration
# The 352-th iteration
# The 353-th iteration
# The 354-th iteration
# The 355-th iteration
# The 356-th iteration
# The 357-th iteration
# The 358-th iteration
# The 359-th iteration
# The 360-th iteration
# The 361-th iteration
# The 362-th iteration
# The 363-th iteration
# The 364-th iteration
# The 365-th iteration
# The 366-th iteration
# The 367-th iteration
# The 368-th iteration
# The 369-th iteration
# The 370-th iteration
# The 371-th iteration
# The 372-th iteration
# The 373-th iteration
# The 374-th iteration
# The 375-th iteration
# The 376-th iteration
# The 377-th iteration
# The 378-th iteration
# The 379-th iteration
# The 380-th iteration
# The 381-th iteration
# The 382-th iteration
# The 383-th iteration
# The 384-th iteration
# The 385-th iteration
# The 386-th iteration
# The 387-th iteration
# The 388-th iteration
# The 389-th iteration
# The 390-th iteration
# The 391-th iteration
# The 392-th iteration
# The 393-th iteration
# The 394-th iteration
# The 395-th iteration
# The 396-th iteration
# The 397-th iteration
# The 398-th iteration
# The 399-th iteration
# The 400-th iteration
# The 401-th iteration
# The 402-th iteration
# The 403-th iteration
# The 404-th iteration
# The 405-th iteration
# The 406-th iteration
# The 407-th iteration
# The 408-th iteration
# The 409-th iteration
# The 410-th iteration
# The 411-th iteration
# The 412-th iteration
# The 413-th iteration
# The 414-th iteration
# The 415-th iteration
# The 416-th iteration
# The 417-th iteration
# The 418-th iteration
# The 419-th iteration
# The 420-th iteration
# The 421-th iteration
# The 422-th iteration
# The 423-th iteration
# The 424-th iteration
# The 425-th iteration
# The 426-th iteration
# The 427-th iteration
# The 428-th iteration
# The 429-th iteration
# The 430-th iteration
# The 431-th iteration
# The 432-th iteration
# The 433-th iteration
# The 434-th iteration
# The 435-th iteration
# The 436-th iteration
# The 437-th iteration
# The 438-th iteration
# The 439-th iteration
# The 440-th iteration
# The 441-th iteration
# The 442-th iteration
# The 443-th iteration
# The 444-th iteration
# The 445-th iteration
# The 446-th iteration
# The 447-th iteration
# The 448-th iteration
# The 449-th iteration
# The 450-th iteration
# The 451-th iteration
# The 452-th iteration
# The 453-th iteration
# The 454-th iteration
# The 455-th iteration
# The 456-th iteration
# The 457-th iteration
# The 458-th iteration
# The 459-th iteration
# The 460-th iteration
# The 461-th iteration
# The 462-th iteration
# The 463-th iteration
# The 464-th iteration
# The 465-th iteration
# The 466-th iteration
# The 467-th iteration
# The 468-th iteration
# The 469-th iteration
# The 470-th iteration
# The 471-th iteration
# The 472-th iteration
# The 473-th iteration
# The 474-th iteration
# The 475-th iteration
# The 476-th iteration
# The 477-th iteration
# The 478-th iteration
# The 479-th iteration
# The 480-th iteration
# The 481-th iteration
# The 482-th iteration
# The 483-th iteration
# The 484-th iteration
# The 485-th iteration
# The 486-th iteration
# The 487-th iteration
# The 488-th iteration
# The 489-th iteration
# The 490-th iteration
# The 491-th iteration
# The 492-th iteration
# The 493-th iteration
# The 494-th iteration
# The 495-th iteration
# The 496-th iteration
# The 497-th iteration
# The 498-th iteration
# The 499-th iteration
# The 500-th iteration
# The 501-th iteration
# The 502-th iteration
# The 503-th iteration
# The 504-th iteration
# The 505-th iteration
# The 506-th iteration
# The 507-th iteration
# The 508-th iteration
# The 509-th iteration
# The 510-th iteration
# The 511-th iteration
# The 512-th iteration
# The 513-th iteration
# The 514-th iteration
# The 515-th iteration
# The 516-th iteration
# The 517-th iteration
# The 518-th iteration
# The 519-th iteration
# The 520-th iteration
# The 521-th iteration
# The 522-th iteration
# The 523-th iteration
# The 524-th iteration
# The 525-th iteration
# The 526-th iteration
# The 527-th iteration
# The 528-th iteration
# The 529-th iteration
# The 530-th iteration
# The 531-th iteration
# The 532-th iteration
# The 533-th iteration
# The 534-th iteration
# The 535-th iteration
# The 536-th iteration
# The 537-th iteration
# The 538-th iteration
# The 539-th iteration
# The 540-th iteration
# The 541-th iteration
# The 542-th iteration
# The 543-th iteration
# The 544-th iteration
# The 545-th iteration
# The 546-th iteration
# The 547-th iteration
# The 548-th iteration
# The 549-th iteration
# The 550-th iteration
# The 551-th iteration
# The 552-th iteration
# The 553-th iteration
# The 554-th iteration
# The 555-th iteration
# The 556-th iteration
# The 557-th iteration
# The 558-th iteration
# The 559-th iteration
# The 560-th iteration
# The 561-th iteration
# The 562-th iteration
# The 563-th iteration
# The 564-th iteration
# The 565-th iteration
# The 566-th iteration
# The 567-th iteration
# The 568-th iteration
# The 569-th iteration
# The 570-th iteration
# The 571-th iteration
# The 572-th iteration
# The 573-th iteration
# The 574-th iteration
# The 575-th iteration
# The 576-th iteration
# The 577-th iteration
# The 578-th iteration
# The 579-th iteration
# The 580-th iteration
# The 581-th iteration
# The 582-th iteration
# The 583-th iteration
# The 584-th iteration
# The 585-th iteration
# The 586-th iteration
# The 587-th iteration
# The 588-th iteration
# The 589-th iteration
# The 590-th iteration
# The 591-th iteration
# The 592-th iteration
# The 593-th iteration
# The 594-th iteration
# The 595-th iteration
# The 596-th iteration
# The 597-th iteration
# The 598-th iteration
# The 599-th iteration
# The 600-th iteration
# The 601-th iteration
# The 602-th iteration
# The 603-th iteration
# The 604-th iteration
# The 605-th iteration
# The 606-th iteration
# The 607-th iteration
# The 608-th iteration
# The 609-th iteration
# The 610-th iteration
# The 611-th iteration
# The 612-th iteration
# The 613-th iteration
# The 614-th iteration
# The 615-th iteration
# The 616-th iteration
# The 617-th iteration
# The 618-th iteration
# The 619-th iteration
# The 620-th iteration
# The 621-th iteration
# The 622-th iteration
# The 623-th iteration
# The 624-th iteration
# The 625-th iteration
# The 626-th iteration
# The 627-th iteration
# The 628-th iteration
# The 629-th iteration
# The 630-th iteration
# The 631-th iteration
# The 632-th iteration
# The 633-th iteration
# The 634-th iteration
# The 635-th iteration
# The 636-th iteration
# The 637-th iteration
# The 638-th iteration
# The 639-th iteration
# The 640-th iteration
# The 641-th iteration
# The 642-th iteration
# The 643-th iteration
# The 644-th iteration
# The 645-th iteration
# The 646-th iteration
# The 647-th iteration
# The 648-th iteration
# The 649-th iteration
# The 650-th iteration
# The 651-th iteration
# The 652-th iteration
# The 653-th iteration
# The 654-th iteration
# The 655-th iteration
# The 656-th iteration
# The 657-th iteration
# The 658-th iteration
# The 659-th iteration
# The 660-th iteration
# The 661-th iteration
# The 662-th iteration
# The 663-th iteration
# The 664-th iteration
# The 665-th iteration
# The 666-th iteration
# The 667-th iteration
# The 668-th iteration
# The 669-th iteration
# The 670-th iteration
# The 671-th iteration
# The 672-th iteration
# The 673-th iteration
# The 674-th iteration
# The 675-th iteration
# The 676-th iteration
# The 677-th iteration
# The 678-th iteration
# The 679-th iteration
# The 680-th iteration
# The 681-th iteration
# The 682-th iteration
# The 683-th iteration
# The 684-th iteration
# The 685-th iteration
# The 686-th iteration
# The 687-th iteration
# The 688-th iteration
# The 689-th iteration
# The 690-th iteration
# The 691-th iteration
# The 692-th iteration
# The 693-th iteration
# The 694-th iteration
# The 695-th iteration
# The 696-th iteration
# The 697-th iteration
# The 698-th iteration
# The 699-th iteration
# The 700-th iteration
# The 701-th iteration
# The 702-th iteration
# The 703-th iteration
# The 704-th iteration
# The 705-th iteration
# The 706-th iteration
# The 707-th iteration
# The 708-th iteration
# The 709-th iteration
# The 710-th iteration
# The 711-th iteration
# The 712-th iteration
# The 713-th iteration
# The 714-th iteration
# The 715-th iteration
# The 716-th iteration
# The 717-th iteration
# The 718-th iteration
# The 719-th iteration
# The 720-th iteration
# The 721-th iteration
# The 722-th iteration
# The 723-th iteration
# The 724-th iteration
# The 725-th iteration
# The 726-th iteration
# The 727-th iteration
# The 728-th iteration
# The 729-th iteration
# The 730-th iteration
# The 731-th iteration
# The 732-th iteration
# The 733-th iteration
# The 734-th iteration
# The 735-th iteration
# The 736-th iteration
# The 737-th iteration
# The 738-th iteration
# The 739-th iteration
# The 740-th iteration
# The 741-th iteration
# The 742-th iteration
# The 743-th iteration
# The 744-th iteration
# The 745-th iteration
# The 746-th iteration
# The 747-th iteration
# The 748-th iteration
# The 749-th iteration
# The 750-th iteration
# The 751-th iteration
# The 752-th iteration
# The 753-th iteration
# The 754-th iteration
# The 755-th iteration
# The 756-th iteration
# The 757-th iteration
# The 758-th iteration
# The 759-th iteration
# The 760-th iteration
# The 761-th iteration
# The 762-th iteration
# The 763-th iteration
# The 764-th iteration
# The 765-th iteration
# The 766-th iteration
# The 767-th iteration
# The 768-th iteration
# The 769-th iteration
# The 770-th iteration
# The 771-th iteration
# The 772-th iteration
# The 773-th iteration
# The 774-th iteration
# The 775-th iteration
# The 776-th iteration
# The 777-th iteration
# The 778-th iteration
# The 779-th iteration
# The 780-th iteration
# The 781-th iteration
# The 782-th iteration
# The 783-th iteration
# The 784-th iteration
# The 785-th iteration
# The 786-th iteration
# The 787-th iteration
# The 788-th iteration
# The 789-th iteration
# The 790-th iteration
# The 791-th iteration
# The 792-th iteration
# The 793-th iteration
# The 794-th iteration
# The 795-th iteration
# The 796-th iteration
# The 797-th iteration
# The 798-th iteration
# The 799-th iteration
# The 800-th iteration
# The 801-th iteration
# The 802-th iteration
# The 803-th iteration
# The 804-th iteration
# The 805-th iteration
# The 806-th iteration
# The 807-th iteration
# The 808-th iteration
# The 809-th iteration
# The 810-th iteration
# The 811-th iteration
# The 812-th iteration
# The 813-th iteration
# The 814-th iteration
# The 815-th iteration
# The 816-th iteration
# The 817-th iteration
# The 818-th iteration
# The 819-th iteration
# The 820-th iteration
# The 821-th iteration
# The 822-th iteration
# The 823-th iteration
# The 824-th iteration
# The 825-th iteration
# The 826-th iteration
# The 827-th iteration
# The 828-th iteration
# The 829-th iteration
# The 830-th iteration
# The 831-th iteration
# The 832-th iteration
# The 833-th iteration
# The 834-th iteration
# The 835-th iteration
# The 836-th iteration
# The 837-th iteration
# The 838-th iteration
# The 839-th iteration
# The 840-th iteration
# The 841-th iteration
# The 842-th iteration
# The 843-th iteration
# The 844-th iteration
# The 845-th iteration
# The 846-th iteration
# The 847-th iteration
# The 848-th iteration
# The 849-th iteration
# The 850-th iteration
# The 851-th iteration
# The 852-th iteration
# The 853-th iteration
# The 854-th iteration
# The 855-th iteration
# The 856-th iteration
# The 857-th iteration
# The 858-th iteration
# The 859-th iteration
# The 860-th iteration
# The 861-th iteration
# The 862-th iteration
# The 863-th iteration
# The 864-th iteration
# The 865-th iteration
# The 866-th iteration
# The 867-th iteration
# The 868-th iteration
# The 869-th iteration
# The 870-th iteration
# The 871-th iteration
# The 872-th iteration
# The 873-th iteration
# The 874-th iteration
# The 875-th iteration
# The 876-th iteration
# The 877-th iteration
# The 878-th iteration
# The 879-th iteration
# The 880-th iteration
# The 881-th iteration
# The 882-th iteration
# The 883-th iteration
# The 884-th iteration
# The 885-th iteration
# The 886-th iteration
# The 887-th iteration
# The 888-th iteration
# The 889-th iteration
# The 890-th iteration
# The 891-th iteration
# The 892-th iteration
# The 893-th iteration
# The 894-th iteration
# The 895-th iteration
# The 896-th iteration
# The 897-th iteration
# The 898-th iteration
# The 899-th iteration
# The 900-th iteration
# The 901-th iteration
# The 902-th iteration
# The 903-th iteration
# The 904-th iteration
# The 905-th iteration
# The 906-th iteration
# The 907-th iteration
# The 908-th iteration
# The 909-th iteration
# The 910-th iteration
# The 911-th iteration
# The 912-th iteration
# The 913-th iteration
# The 914-th iteration
# The 915-th iteration
# The 916-th iteration
# The 917-th iteration
# The 918-th iteration
# The 919-th iteration
# The 920-th iteration
# The 921-th iteration
# The 922-th iteration
# The 923-th iteration
# The 924-th iteration
# The 925-th iteration
# The 926-th iteration
# The 927-th iteration
# The 928-th iteration
# The 929-th iteration
# The 930-th iteration
# The 931-th iteration
# The 932-th iteration
# The 933-th iteration
# The 934-th iteration
# The 935-th iteration
# The 936-th iteration
# The 937-th iteration
# The 938-th iteration
# The 939-th iteration
# The 940-th iteration
# The 941-th iteration
# The 942-th iteration
# The 943-th iteration
# The 944-th iteration
# The 945-th iteration
# The 946-th iteration
# The 947-th iteration
# The 948-th iteration
# The 949-th iteration
# The 950-th iteration
# The 951-th iteration
# The 952-th iteration
# The 953-th iteration
# The 954-th iteration
# The 955-th iteration
# The 956-th iteration
# The 957-th iteration
# The 958-th iteration
# The 959-th iteration
# The 960-th iteration
# The 961-th iteration
# The 962-th iteration
# The 963-th iteration
# The 964-th iteration
# The 965-th iteration
# The 966-th iteration
# The 967-th iteration
# The 968-th iteration
# The 969-th iteration
# The 970-th iteration
# The 971-th iteration
# The 972-th iteration
# The 973-th iteration
# The 974-th iteration
# The 975-th iteration
# The 976-th iteration
# The 977-th iteration
# The 978-th iteration
# The 979-th iteration
# The 980-th iteration
# The 981-th iteration
# The 982-th iteration
# The 983-th iteration
# The 984-th iteration
# The 985-th iteration
# The 986-th iteration
# The 987-th iteration
# The 988-th iteration
# The 989-th iteration
# The 990-th iteration
# The 991-th iteration
# The 992-th iteration
# The 993-th iteration
# The 994-th iteration
# The 995-th iteration
# The 996-th iteration
# The 997-th iteration
# The 998-th iteration
# The 999-th iteration
# The 1000-th iteration
# The 1001-th iteration
# The 1002-th iteration
# The 1003-th iteration
# The 1004-th iteration
# The 1005-th iteration
# The 1006-th iteration
# The 1007-th iteration
# The 1008-th iteration
# The 1009-th iteration
# The 1010-th iteration
# The 1011-th iteration
# The 1012-th iteration
# The 1013-th iteration
# The 1014-th iteration
# The 1015-th iteration
# The 1016-th iteration
# The 1017-th iteration
# The 1018-th iteration
# The 1019-th iteration
# The 1020-th iteration
# The 1021-th iteration
# The 1022-th iteration
# The 1023-th iteration
# The 1024-th iteration
# The 1025-th iteration
# The 1026-th iteration
# The 1027-th iteration
# The 1028-th iteration
# The 1029-th iteration
# The 1030-th iteration
# The 1031-th iteration
# The 1032-th iteration
# The 1033-th iteration
# The 1034-th iteration
# The 1035-th iteration
# The 1036-th iteration
# The 1037-th iteration
# The 1038-th iteration
# The 1039-th iteration
# The 1040-th iteration
# The 1041-th iteration
# The 1042-th iteration
# The 1043-th iteration
# The 1044-th iteration
# The 1045-th iteration
# The 1046-th iteration
# The 1047-th iteration
# The 1048-th iteration
# The 1049-th iteration
# The 1050-th iteration
# The 1051-th iteration
# The 1052-th iteration
# The 1053-th iteration
# The 1054-th iteration
# The 1055-th iteration
# The 1056-th iteration
# The 1057-th iteration
# The 1058-th iteration
# The 1059-th iteration
# The 1060-th iteration
# The 1061-th iteration
# The 1062-th iteration
# The 1063-th iteration
# The 1064-th iteration
# The 1065-th iteration
# The 1066-th iteration
# The 1067-th iteration
# The 1068-th iteration
# The 1069-th iteration
# The 1070-th iteration
# The 1071-th iteration
# The 1072-th iteration
# The 1073-th iteration
# The 1074-th iteration
# The 1075-th iteration
# The 1076-th iteration
# The 1077-th iteration
# The 1078-th iteration
# The 1079-th iteration
# The 1080-th iteration
# The 1081-th iteration
# The 1082-th iteration
# The 1083-th iteration
# The 1084-th iteration
# The 1085-th iteration
# The 1086-th iteration
# The 1087-th iteration
# The 1088-th iteration
# The 1089-th iteration
# The 1090-th iteration
# The 1091-th iteration
# The 1092-th iteration
# The 1093-th iteration
# The 1094-th iteration
# The 1095-th iteration
# The 1096-th iteration
# The 1097-th iteration
# The 1098-th iteration
# The 1099-th iteration
# The 1100-th iteration
# The 1101-th iteration
# The 1102-th iteration
# The 1103-th iteration
# The 1104-th iteration
# The 1105-th iteration
# The 1106-th iteration
# The 1107-th iteration
# The 1108-th iteration
# The 1109-th iteration
# The 1110-th iteration
# The 1111-th iteration
# The 1112-th iteration
# The 1113-th iteration
# The 1114-th iteration
# The 1115-th iteration
# The 1116-th iteration
# The 1117-th iteration
# The 1118-th iteration
# The 1119-th iteration
# The 1120-th iteration
# The 1121-th iteration
# The 1122-th iteration
# The 1123-th iteration
# The 1124-th iteration
# The 1125-th iteration
# The 1126-th iteration
# The 1127-th iteration
# The 1128-th iteration
# The 1129-th iteration
# The 1130-th iteration
# The 1131-th iteration
# The 1132-th iteration
# The 1133-th iteration
# The 1134-th iteration
# The 1135-th iteration
# The 1136-th iteration
# The 1137-th iteration
# The 1138-th iteration
# The 1139-th iteration
# The 1140-th iteration
# The 1141-th iteration
# The 1142-th iteration
# The 1143-th iteration
# The 1144-th iteration
# The 1145-th iteration
# The 1146-th iteration
# The 1147-th iteration
# The 1148-th iteration
# The 1149-th iteration
# The 1150-th iteration
# The 1151-th iteration
# The 1152-th iteration
# The 1153-th iteration
# The 1154-th iteration
# The 1155-th iteration
# The 1156-th iteration
# The 1157-th iteration
# The 1158-th iteration
# The 1159-th iteration
# The 1160-th iteration
# The 1161-th iteration
# The 1162-th iteration
# The 1163-th iteration
# The 1164-th iteration
# The 1165-th iteration
# The 1166-th iteration
# The 1167-th iteration
# The 1168-th iteration
# The 1169-th iteration
# The 1170-th iteration
# The 1171-th iteration
# The 1172-th iteration
# The 1173-th iteration
# The 1174-th iteration
# The 1175-th iteration
# The 1176-th iteration
# The 1177-th iteration
# The 1178-th iteration
# The 1179-th iteration
# The 1180-th iteration
# The 1181-th iteration
# The 1182-th iteration
# The 1183-th iteration
# The 1184-th iteration
# The 1185-th iteration
# The 1186-th iteration
# The 1187-th iteration
# The 1188-th iteration
# The 1189-th iteration
# The 1190-th iteration
# The 1191-th iteration
# The 1192-th iteration
# The 1193-th iteration
# The 1194-th iteration
# The 1195-th iteration
# The 1196-th iteration
# The 1197-th iteration
# The 1198-th iteration
# The 1199-th iteration
# The 1200-th iteration
# The 1201-th iteration
# The 1202-th iteration
# The 1203-th iteration
# The 1204-th iteration
# The 1205-th iteration
# The 1206-th iteration
# The 1207-th iteration
# The 1208-th iteration
# The 1209-th iteration
# The 1210-th iteration
# The 1211-th iteration
# The 1212-th iteration
# The 1213-th iteration
# The 1214-th iteration
# The 1215-th iteration
# The 1216-th iteration
# The 1217-th iteration
# The 1218-th iteration
# The 1219-th iteration
# The 1220-th iteration
# The 1221-th iteration
# The 1222-th iteration
# The 1223-th iteration
# The 1224-th iteration
# The 1225-th iteration
# The 1226-th iteration
# The 1227-th iteration
# The 1228-th iteration
# The 1229-th iteration
# The 1230-th iteration
# The 1231-th iteration
# The 1232-th iteration
# The 1233-th iteration
# The 1234-th iteration
# The 1235-th iteration
# The 1236-th iteration
# The 1237-th iteration
# The 1238-th iteration
# The 1239-th iteration
# The 1240-th iteration
# The 1241-th iteration
# The 1242-th iteration
# The 1243-th iteration
# The 1244-th iteration
# The 1245-th iteration
# The 1246-th iteration
# The 1247-th iteration
# The 1248-th iteration
# The 1249-th iteration
# The 1250-th iteration
# The 1251-th iteration
# The 1252-th iteration
# The 1253-th iteration
# The 1254-th iteration
# The 1255-th iteration
# The 1256-th iteration
# The 1257-th iteration
# The 1258-th iteration
# The 1259-th iteration
# The 1260-th iteration
# The 1261-th iteration
# The 1262-th iteration
# The 1263-th iteration
# The 1264-th iteration
# The 1265-th iteration
# The 1266-th iteration
# The 1267-th iteration
# The 1268-th iteration
# The 1269-th iteration
# The 1270-th iteration
# The 1271-th iteration
# The 1272-th iteration
# The 1273-th iteration
# The 1274-th iteration
# The 1275-th iteration
# The 1276-th iteration
# The 1277-th iteration
# The 1278-th iteration
# The 1279-th iteration
# The 1280-th iteration
# The 1281-th iteration
# The 1282-th iteration
# The 1283-th iteration
# The 1284-th iteration
# The 1285-th iteration
# The 1286-th iteration
# The 1287-th iteration
# The 1288-th iteration
# The 1289-th iteration
# The 1290-th iteration
# The 1291-th iteration
# The 1292-th iteration
# The 1293-th iteration
# The 1294-th iteration
# The 1295-th iteration
# The 1296-th iteration
# The 1297-th iteration
# The 1298-th iteration
# The 1299-th iteration
# The 1300-th iteration
# The 1301-th iteration
# The 1302-th iteration
# The 1303-th iteration
# The 1304-th iteration
# The 1305-th iteration
# The 1306-th iteration
# The 1307-th iteration
# The 1308-th iteration
# The 1309-th iteration
# The 1310-th iteration
# The 1311-th iteration
# The 1312-th iteration
# The 1313-th iteration
# The 1314-th iteration
# The 1315-th iteration
# The 1316-th iteration
# The 1317-th iteration
# The 1318-th iteration
# The 1319-th iteration
# The 1320-th iteration
# The 1321-th iteration
# The 1322-th iteration
# The 1323-th iteration
# The 1324-th iteration
# The 1325-th iteration
# The 1326-th iteration
# The 1327-th iteration
# The 1328-th iteration
# The 1329-th iteration
# The 1330-th iteration
# The 1331-th iteration
# The 1332-th iteration
# The 1333-th iteration
# The 1334-th iteration
# The 1335-th iteration
# The 1336-th iteration
# The 1337-th iteration
# The 1338-th iteration
# The 1339-th iteration
# The 1340-th iteration
# The 1341-th iteration
# The 1342-th iteration
# The 1343-th iteration
# The 1344-th iteration
# The 1345-th iteration
# The 1346-th iteration
# The 1347-th iteration
# The 1348-th iteration
# The 1349-th iteration
# The 1350-th iteration
# The 1351-th iteration
# The 1352-th iteration
# The 1353-th iteration
# The 1354-th iteration
# The 1355-th iteration
# The 1356-th iteration
# The 1357-th iteration
# The 1358-th iteration
# The 1359-th iteration
# The 1360-th iteration
# The 1361-th iteration
# The 1362-th iteration
# The 1363-th iteration
# The 1364-th iteration
# The 1365-th iteration
# The 1366-th iteration
# The 1367-th iteration
# The 1368-th iteration
# The 1369-th iteration
# The 1370-th iteration
# The 1371-th iteration
# The 1372-th iteration
# The 1373-th iteration
# The 1374-th iteration
# The 1375-th iteration
# The 1376-th iteration
# The 1377-th iteration
# The 1378-th iteration
# The 1379-th iteration
# The 1380-th iteration
# The 1381-th iteration
# The 1382-th iteration
# The 1383-th iteration
# The 1384-th iteration
# The 1385-th iteration
# The 1386-th iteration
# The 1387-th iteration
# The 1388-th iteration
# The 1389-th iteration
# The 1390-th iteration
# The 1391-th iteration
# The 1392-th iteration
# The 1393-th iteration
# The 1394-th iteration
# The 1395-th iteration
# The 1396-th iteration
# The 1397-th iteration
# The 1398-th iteration
# The 1399-th iteration
# Avg. time: 0.008691341706684657
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-60ffd08acd70> in <cell line: 19>()
#      79     psnr_content = load_name + ": " + str(psnr_ave) + "\n"
#      80     ssim_content = load_name + ": " + str(ssim_ave) + "\n"
# ---> 81     text_save(content = psnr_content, filename = psnr_file)
#      82     text_save(content = ssim_content, filename = ssim_file)
#      83
#
# <ipython-input-14-0fb6468716f9> in text_save(content, filename, mode)
#     196     # save a list to a txt
#     197     # Try to save a list variable in txt file.
# --> 198     file = open(filename, mode)
#     199     for i in range(len(content)):
#     200         file.write(str(content[i]))
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/psnr_data.txt'

# %%
psnr_ave = psnr_sum / eval_cnt
ssim_ave = ssim_sum / eval_cnt
psnr_file = "./derain/psnr_data.txt"
ssim_file = "./derain/ssim_data.txt"
psnr_content = load_name + ": " + str(psnr_ave) + "\n"
ssim_content = load_name + ": " + str(ssim_ave) + "\n"
text_save(content = psnr_content, filename = psnr_file)
text_save(content = ssim_content, filename = ssim_file)
